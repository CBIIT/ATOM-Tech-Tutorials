# %% [markdown]
# # QMUGs_Data EDA

# %% [markdown]
# ## Import packages

# %%
# We temporarily disable warnings for demonstration.
# FutureWarnings and DeprecationWarnings are present from some of the AMPL 
# dependency modules.
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline
# manipulate data
import pandas as pd
import json
import requests
import io
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib_venn as mpv
from scipy.stats import pearsonr
import numpy as np
import getpass, os

# set up visualization parameters
sns.set_context("paper")
sns.set_style("whitegrid")
sns.set_palette("Set2")
pal = sns.color_palette()
plt.rcParams['figure.figsize'] = [10,10]

pd.set_option('display.max_columns',(90))
pd.set_option('display.max_rows',(20))

# %%
sns.palplot(pal)

# %%
# Import AMPL libraries
import atomsci.ddm.utils.data_curation_functions as dcf
import atomsci.ddm.utils.curate_data as curate_data
import atomsci.ddm.pipeline.diversity_plots as dp
import atomsci.ddm.pipeline.chem_diversity as cd
import atomsci.ddm.pipeline.model_pipeline as mp
import atomsci.ddm.pipeline.parameter_parser as parse
import atomsci.ddm.utils.struct_utils as struct_utils
from atomsci.ddm.pipeline import perf_plots as pp
# Out:
# Skipped loading modules with pytorch-geometric dependency, missing a dependency. No module named 'torch_geometric'
# Skipped loading modules with pytorch-geometric dependency, missing a dependency. cannot import name 'DMPNN' from 'deepchem.models.torch_models' (/home/jupyter/atomsci/lib/python3.8/site-packages/deepchem/models/torch_models/__init__.py)
# Skipped loading modules with pytorch-lightning dependency, missing a dependency. No module named 'pytorch_lightning'
# Skipped loading some Jax models, missing a dependency. jax requires jaxlib to be installed. See https://github.com/google/jax#installation for installation instructions.

# %%
! pip install rdkit-pypi
! pip install --pre deepchem

import deepchem
# print(deepchem.__version__)
! pip install umap
! pip install llvmlite==0.35.0  --ignore-installed
! pip install umap-learn
! pip install molvs
! pip install bravado
# Out:
# Requirement already satisfied: rdkit-pypi in /opt/conda/lib/python3.10/site-packages (2022.9.5)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from rdkit-pypi) (1.23.5)
# Requirement already satisfied: Pillow in /opt/conda/lib/python3.10/site-packages (from rdkit-pypi) (10.0.0)
# Requirement already satisfied: deepchem in /opt/conda/lib/python3.10/site-packages (2.7.2.dev20231020164241)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.10/site-packages (from deepchem) (1.3.2)
# Requirement already satisfied: numpy>=1.21 in /opt/conda/lib/python3.10/site-packages (from deepchem) (1.23.5)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from deepchem) (2.0.3)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.10/site-packages (from deepchem) (1.3.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from deepchem) (1.12)
# Requirement already satisfied: scipy>=1.10.1 in /opt/conda/lib/python3.10/site-packages (from deepchem) (1.11.2)
# Requirement already satisfied: rdkit in /opt/conda/lib/python3.10/site-packages (from deepchem) (2023.3.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas->deepchem) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->deepchem) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.10/site-packages (from pandas->deepchem) (2023.3)
# Requirement already satisfied: Pillow in /opt/conda/lib/python3.10/site-packages (from rdkit->deepchem) (10.0.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->deepchem) (3.2.0)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->deepchem) (1.3.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->deepchem) (1.16.0)
# Requirement already satisfied: umap in /opt/conda/lib/python3.10/site-packages (0.1.1)
# Collecting llvmlite==0.35.0
#   Using cached llvmlite-0.35.0.tar.gz (121 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: llvmlite
#   Building wheel for llvmlite (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [26 lines of output]
#       running bdist_wheel
#       /opt/conda/bin/python3.10 /var/tmp/pip-install-sdtece28/llvmlite_964ccf827a7243d5b6a4af1236c52f27/ffi/build.py
#       LLVM version... Traceback (most recent call last):
#         File "/var/tmp/pip-install-sdtece28/llvmlite_964ccf827a7243d5b6a4af1236c52f27/ffi/build.py", line 105, in main_posix
#           out = subprocess.check_output([llvm_config, '--version'])
#         File "/opt/conda/lib/python3.10/subprocess.py", line 421, in check_output
#           return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#         File "/opt/conda/lib/python3.10/subprocess.py", line 503, in run
#           with Popen(*popenargs, **kwargs) as process:
#         File "/opt/conda/lib/python3.10/subprocess.py", line 971, in __init__
#           self._execute_child(args, executable, preexec_fn, close_fds,
#         File "/opt/conda/lib/python3.10/subprocess.py", line 1863, in _execute_child
#           raise child_exception_type(errno_num, err_msg, err_filename)
#       FileNotFoundError: [Errno 2] No such file or directory: 'llvm-config'
#
#       During handling of the above exception, another exception occurred:
#
#       Traceback (most recent call last):
#         File "/var/tmp/pip-install-sdtece28/llvmlite_964ccf827a7243d5b6a4af1236c52f27/ffi/build.py", line 191, in <module>
#           main()
#         File "/var/tmp/pip-install-sdtece28/llvmlite_964ccf827a7243d5b6a4af1236c52f27/ffi/build.py", line 181, in main
#           main_posix('linux', '.so')
#         File "/var/tmp/pip-install-sdtece28/llvmlite_964ccf827a7243d5b6a4af1236c52f27/ffi/build.py", line 107, in main_posix
#           raise RuntimeError("%s failed executing, please point LLVM_CONFIG "
#       RuntimeError: llvm-config failed executing, please point LLVM_CONFIG to the path for llvm-config
#       error: command '/opt/conda/bin/python3.10' failed with exit code 1
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for llvmlite
#   Running setup.py clean for llvmlite
# Failed to build llvmlite
# ERROR: Could not build wheels for llvmlite, which is required to install pyproject.toml-based projects
# Requirement already satisfied: umap-learn in /opt/conda/lib/python3.10/site-packages (0.5.4)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.10/site-packages (from umap-learn) (1.23.5)
# Requirement already satisfied: scipy>=1.3.1 in /opt/conda/lib/python3.10/site-packages (from umap-learn) (1.11.2)
# Requirement already satisfied: scikit-learn>=0.22 in /opt/conda/lib/python3.10/site-packages (from umap-learn) (1.3.0)
# Requirement already satisfied: numba>=0.51.2 in /opt/conda/lib/python3.10/site-packages (from umap-learn) (0.57.1)
# Requirement already satisfied: pynndescent>=0.5 in /opt/conda/lib/python3.10/site-packages (from umap-learn) (0.5.10)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from umap-learn) (4.66.1)
# Requirement already satisfied: tbb>=2019.0 in /opt/conda/lib/python3.10/site-packages (from umap-learn) (2021.10.0)
# Requirement already satisfied: llvmlite<0.41,>=0.40.0dev0 in /opt/conda/lib/python3.10/site-packages (from numba>=0.51.2->umap-learn) (0.40.1)
# Requirement already satisfied: joblib>=0.11 in /opt/conda/lib/python3.10/site-packages (from pynndescent>=0.5->umap-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=0.22->umap-learn) (3.2.0)
# Requirement already satisfied: molvs in /opt/conda/lib/python3.10/site-packages (0.1.1)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from molvs) (1.16.0)
# Requirement already satisfied: bravado in /opt/conda/lib/python3.10/site-packages (11.0.3)
# Requirement already satisfied: bravado-core>=5.16.1 in /opt/conda/lib/python3.10/site-packages (from bravado) (6.1.0)
# Requirement already satisfied: msgpack in /opt/conda/lib/python3.10/site-packages (from bravado) (1.0.5)
# Requirement already satisfied: python-dateutil in /opt/conda/lib/python3.10/site-packages (from bravado) (2.8.2)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from bravado) (6.0.1)
# Requirement already satisfied: requests>=2.17 in /opt/conda/lib/python3.10/site-packages (from bravado) (2.31.0)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from bravado) (1.16.0)
# Requirement already satisfied: simplejson in /opt/conda/lib/python3.10/site-packages (from bravado) (3.19.2)
# Requirement already satisfied: monotonic in /opt/conda/lib/python3.10/site-packages (from bravado) (1.6)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from bravado) (4.7.1)
# Requirement already satisfied: jsonref in /opt/conda/lib/python3.10/site-packages (from bravado-core>=5.16.1->bravado) (1.1.0)
# Requirement already satisfied: jsonschema[format]>=2.5.1 in /opt/conda/lib/python3.10/site-packages (from bravado-core>=5.16.1->bravado) (4.19.0)
# Requirement already satisfied: pytz in /opt/conda/lib/python3.10/site-packages (from bravado-core>=5.16.1->bravado) (2023.3)
# Requirement already satisfied: swagger-spec-validator>=2.0.1 in /opt/conda/lib/python3.10/site-packages (from bravado-core>=5.16.1->bravado) (3.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.17->bravado) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.17->bravado) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.17->bravado) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.17->bravado) (2023.7.22)
# Requirement already satisfied: attrs>=22.2.0 in /opt/conda/lib/python3.10/site-packages (from jsonschema[format]>=2.5.1->bravado-core>=5.16.1->bravado) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/lib/python3.10/site-packages (from jsonschema[format]>=2.5.1->bravado-core>=5.16.1->bravado) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/conda/lib/python3.10/site-packages (from jsonschema[format]>=2.5.1->bravado-core>=5.16.1->bravado) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/conda/lib/python3.10/site-packages (from jsonschema[format]>=2.5.1->bravado-core>=5.16.1->bravado) (0.9.2)
# Requirement already satisfied: fqdn in /opt/conda/lib/python3.10/site-packages (from jsonschema[format]>=2.5.1->bravado-core>=5.16.1->bravado) (1.5.1)
# Requirement already satisfied: isoduration in /opt/conda/lib/python3.10/site-packages (from jsonschema[format]>=2.5.1->bravado-core>=5.16.1->bravado) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /opt/conda/lib/python3.10/site-packages (from jsonschema[format]>=2.5.1->bravado-core>=5.16.1->bravado) (2.0)
# Requirement already satisfied: rfc3339-validator in /opt/conda/lib/python3.10/site-packages (from jsonschema[format]>=2.5.1->bravado-core>=5.16.1->bravado) (0.1.4)
# Requirement already satisfied: rfc3987 in /opt/conda/lib/python3.10/site-packages (from jsonschema[format]>=2.5.1->bravado-core>=5.16.1->bravado) (1.3.8)
# Requirement already satisfied: uri-template in /opt/conda/lib/python3.10/site-packages (from jsonschema[format]>=2.5.1->bravado-core>=5.16.1->bravado) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in /opt/conda/lib/python3.10/site-packages (from jsonschema[format]>=2.5.1->bravado-core>=5.16.1->bravado) (1.13)
# Requirement already satisfied: arrow>=0.15.0 in /opt/conda/lib/python3.10/site-packages (from isoduration->jsonschema[format]>=2.5.1->bravado-core>=5.16.1->bravado) (1.2.3)

# %%
import deepchem as dc

# get the Install AMPL_GPU_test.sh
# !wget https://raw.githubusercontent.com/ravichas/AMPL-Tutorial/master/config/install_AMPL_GPU_test.sh

# run the script to install AMPL
! chmod u+x install_AMPL_GPU_test.sh
! ./install_AMPL_GPU_test.sh
# Out:
# --2023-12-08 21:25:13--  https://raw.githubusercontent.com/ravichas/AMPL-Tutorial/master/config/install_AMPL_GPU_test.sh
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1127 (1.1K) [text/plain]
# Saving to: ‘install_AMPL_GPU_test.sh.9’
#
# install_AMPL_GPU_te 100%[===================>]   1.10K  --.-KB/s    in 0s
#
# 2023-12-08 21:25:13 (57.6 MB/s) - ‘install_AMPL_GPU_test.sh.9’ saved [1127/1127]
#
# mkdir: cannot create directory ‘github’: File exists
# fatal: destination path 'AMPL' already exists and is not an empty directory.
# error: pathspec 'deepchem_25' did not match any file(s) known to git
# patch: **** Can't create temporary file /content/github/AMPL/atomsci/ddm/pipeline/transformations.py.oPVyFMR : No such file or directory
# patch: **** Can't create temporary file /content/github/AMPL/atomsci/ddm/__init__.py.oT8PLOU : No such file or directory
# ./install_AMPL_GPU_test.sh: line 42: cd: /content/github/AMPL: No such file or directory
# fatal: not a git repository (or any parent up to mount point /home)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# ./install_AMPL_GPU_test.sh: line 44: ./build.sh: No such file or directory
# ./install_AMPL_GPU_test.sh: line 45: ./install.sh: No such file or directory

# %% [markdown]
# ## Load data

# %%
os.getcwd()
# Out:
# '/home/jupyter'

# %%
# load the dataset
data = pd.read_csv("qmugs_rdkit_smiles.csv", sep=',', header=0)

# %% [markdown]
# ## Explore QMUGs Dataset

# %%
data.shape
# Out:
# (1992984, 70)

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'chembl_id', 'conf_id', 'smiles', 'mw', 'atoms',
#        'heavy_atoms', 'heteroatoms', 'rotatable_bonds', 'stereocenters',
#        'rings', 'hbond_acceptors', 'hbond_donors',
#        'significant_negative_wavenumbers', 'nonunique_smiles',
#        'GFN2_TOTAL_ENERGY', 'GFN2_ATOMIC_ENERGY', 'GFN2_FORMATION_ENERGY',
#        'GFN2_TOTAL_ENTHALPY', 'GFN2_TOTAL_FREE_ENERGY', 'GFN2_DIPOLE_X',
#        'GFN2_DIPOLE_Y', 'GFN2_DIPOLE_Z', 'GFN2_DIPOLE_TOT',
#        'GFN2_QUADRUPOLE_XX', 'GFN2_QUADRUPOLE_XY', 'GFN2_QUADRUPOLE_YY',
#        'GFN2_QUADRUPOLE_XZ', 'GFN2_QUADRUPOLE_yz', 'GFN2_QUADRUPOLE_ZZ',
#        'GFN2_ROT_CONSTANT_A', 'GFN2_ROT_CONSTANT_B', 'GFN2_ROT_CONSTANT_C',
#        'GFN2_ENTHALPY_VIB', 'GFN2_ENTHALPY_ROT', 'GFN2_ENTHALPY_TRANSL',
#        'GFN2_ENTHALPY_TOT', 'GFN2_HEAT_CAPACITY_VIB', 'GFN2_HEAT_CAPACITY_ROT',
#        'GFN2_HEAT_CAPACITY_TRANSL', 'GFN2_HEAT_CAPACITY_TOT',
#        'GFN2_ENTROPY_VIB', 'GFN2_ENTROPY_ROT', 'GFN2_ENTROPY_TRANSL',
#        'GFN2_ENTROPY_TOT', 'GFN2_HOMO_ENERGY', 'GFN2_LUMO_ENERGY',
#        'GFN2_HOMO_LUMO_GAP', 'GFN2_FERMI_LEVEL',
#        'GFN2_DISPERSION_COEFFICIENT_MOLECULAR',
#        'GFN2_POLARIZABILITY_MOLECULAR', 'DFT_TOTAL_ENERGY',
#        'DFT_ATOMIC_ENERGY', 'DFT_FORMATION_ENERGY', 'DFT_DIPOLE_X',
#        'DFT_DIPOLE_Y', 'DFT_DIPOLE_Z', 'DFT_DIPOLE_TOT', 'DFT_ROT_CONSTANT_A',
#        'DFT_ROT_CONSTANT_B', 'DFT_ROT_CONSTANT_C', 'DFT_XC_ENERGY',
#        'DFT_NUCLEAR_REPULSION_ENERGY', 'DFT_ONE_ELECTRON_ENERGY',
#        'DFT_TWO_ELECTRON_ENERGY', 'DFT_HOMO_ENERGY', 'DFT_LUMO_ENERGY',
#        'DFT_HOMO_LUMO_GAP', 'rdkit_smile', 'compound_id'],
#       dtype='object')

# %%
print(data["chembl_id"].value_counts())
# Out:
# CHEMBL1          3
# CHEMBL3885331    3
# CHEMBL3885292    3
# CHEMBL3885294    3
# CHEMBL3885298    3
#                 ..
# CHEMBL3670973    1
# CHEMBL3884092    1
# CHEMBL560305     1
# CHEMBL1453574    1
# CHEMBL3780580    1
# Name: chembl_id, Length: 665911, dtype: int64

# %%
d1 = data.pivot_table(index = 'chembl_id', columns = 'atoms', values='GFN2_HOMO_LUMO_GAP', aggfunc='mean')
display(d1.describe())
# Out:
# atoms       4         5         6         7         8          9          10   \
# count  5.000000  2.000000  3.000000  4.000000  6.000000  12.000000  22.000000
# mean   0.202960  0.158214  0.122354  0.166414  0.183390   0.173947   0.170672
# std    0.038651  0.041967  0.094517  0.055238  0.107746   0.083303   0.074974
# min    0.160939  0.128538  0.067212  0.103885  0.074231   0.057972   0.092601
# 25%    0.163312  0.143376  0.067785  0.130921  0.103589   0.120048   0.128993
# 50%    0.213558  0.158214  0.068359  0.166906  0.148723   0.169925   0.144399
# 75%    0.238494  0.173051  0.149924  0.202399  0.281512   0.194865   0.188087
# max    0.238496  0.187889  0.231490  0.227962  0.314347   0.346867   0.382131
#
# atoms        11         12         13          14          15          16   \
# count  32.000000  46.000000  75.000000  132.000000  225.000000  282.000000
# mean    0.147360   0.124442   0.126710    0.125690    0.124086    0.116628
# std     0.055650   0.045672   0.052771    0.054093    0.037362    0.040531
# min     0.047476   0.039292   0.024056    0.032569    0.053469    0.012251
# 25%     0.109055   0.101835   0.106324    0.093849    0.101422    0.093934
# 50%     0.147877   0.120300   0.128197    0.110959    0.121278    0.116540
# 75%     0.175318   0.148550   0.135910    0.143168    0.138437    0.133647
# max     0.305136   0.223421   0.400388    0.380704    0.350456    0.371821
#
# atoms         17          18          19          20           21   \
# count  404.000000  504.000000  607.000000  903.000000  1057.000000
# mean     0.118820    0.113622    0.110560    0.112567     0.112783
# std      0.047310    0.034952    0.036957    0.046988     0.043963
# min      0.036138    0.014047    0.017454    0.018536     0.015879
# 25%      0.094752    0.091478    0.091239    0.085931     0.089142
# 50%      0.113508    0.111702    0.107120    0.108192     0.108154
# 75%      0.135980    0.131141    0.127703    0.130031     0.128502
# max      0.408467    0.374786    0.396821    0.375943     0.403637
#
# atoms          22           23           24           25           26   \
# count  1200.000000  1477.000000  2055.000000  2267.000000  3023.000000
# mean      0.110085     0.112230     0.110133     0.106478     0.103666
# std       0.038323     0.050068     0.045676     0.036193     0.036599
# min       0.031920     0.026721     0.015705     0.005207     0.012733
# 25%       0.089917     0.087247     0.086402     0.087081     0.084465
# 50%       0.107646     0.105751     0.104255     0.103838     0.101394
# 75%       0.126725     0.124889     0.124880     0.121558     0.117348
# max       0.434803     0.405572     0.409790     0.408693     0.412637
#
# atoms          27           28           29           30           31   \
# count  3610.000000  4332.000000  4824.000000  5741.000000  6419.000000
# mean      0.102400     0.102080     0.100552     0.099577     0.099235
# std       0.036802     0.032969     0.031465     0.030894     0.028352
# min       0.012703     0.009761     0.012282     0.015997     0.010280
# 25%       0.084605     0.085739     0.083392     0.083310     0.084176
# 50%       0.100134     0.100623     0.099736     0.098412     0.098474
# 75%       0.116963     0.115388     0.115114     0.114361     0.113421
# max       0.426803     0.429862     0.399981     0.452211     0.427162
#
# atoms          32           33           34           35           36   \
# count  7060.000000  7777.000000  8523.000000  9085.000000  9816.000000
# mean      0.099204     0.097677     0.097709     0.097395     0.096879
# std       0.029722     0.029073     0.028170     0.027492     0.026325
# min       0.006830     0.003885     0.009508     0.006715     0.011730
# 25%       0.082979     0.081364     0.082256     0.081980     0.081666
# 50%       0.097692     0.096551     0.096695     0.096502     0.096063
# 75%       0.114306     0.112991     0.112434     0.112458     0.111366
# max       0.383806     0.391473     0.413216     0.407577     0.393263
#
# atoms           37            38            39            40            41   \
# count  11093.000000  11451.000000  12018.000000  12893.000000  13976.000000
# mean       0.096030      0.096793      0.096441      0.095762      0.095677
# std        0.025278      0.026019      0.024975      0.024378      0.024370
# min        0.010279      0.014184      0.006594      0.008157      0.007634
# 25%        0.081172      0.082571      0.082210      0.081796      0.081356
# 50%        0.095714      0.095817      0.095740      0.095318      0.095571
# 75%        0.110639      0.110659      0.110488      0.110056      0.109684
# max        0.387031      0.413292      0.378214      0.410072      0.393912
#
# atoms           42            43            44            45            46   \
# count  14699.000000  15226.000000  16205.000000  16142.000000  16781.000000
# mean       0.095806      0.095713      0.095233      0.094527      0.095133
# std        0.024516      0.024011      0.024521      0.023750      0.023595
# min        0.007279      0.005362      0.005725      0.007398      0.008058
# 25%        0.081539      0.081682      0.080874      0.080452      0.081119
# 50%        0.095466      0.095445      0.094798      0.094182      0.095069
# 75%        0.109718      0.109890      0.109516      0.108421      0.110035
# max        0.443155      0.417125      0.396865      0.409285      0.412680
#
# atoms           47            48   ...        179        180        181  \
# count  17161.000000  17696.000000  ...  56.000000  45.000000  45.000000
# mean       0.094777      0.095022  ...   0.096666   0.099260   0.096861
# std        0.023074      0.023429  ...   0.019532   0.019448   0.021605
# min        0.007198      0.006780  ...   0.031557   0.041941   0.006896
# 25%        0.081016      0.081035  ...   0.090740   0.092711   0.090791
# 50%        0.094533      0.094746  ...   0.100564   0.100311   0.099306
# 75%        0.109131      0.109291  ...   0.109418   0.111443   0.109291
# max        0.364692      0.407669  ...   0.125824   0.132567   0.134601
#
# atoms        182        183        184        185        186        187  \
# count  50.000000  48.000000  34.000000  40.000000  33.000000  43.000000
# mean    0.099403   0.092609   0.094149   0.103211   0.090065   0.096316
# std     0.021642   0.020941   0.020484   0.013510   0.025121   0.019361
# min     0.043020   0.043905   0.013848   0.042003   0.029091   0.030184
# 25%     0.093673   0.086100   0.088735   0.098746   0.081420   0.090634
# 50%     0.106889   0.096408   0.098935   0.103035   0.094862   0.098443
# 75%     0.116277   0.104801   0.104982   0.109577   0.105234   0.107694
# max     0.123268   0.123300   0.128304   0.133757   0.139613   0.127742
#
# atoms        188        189        190        191        192        193  \
# count  42.000000  25.000000  32.000000  56.000000  34.000000  43.000000
# mean    0.097006   0.099249   0.102343   0.096376   0.096395   0.105757
# std     0.019782   0.016914   0.017927   0.018933   0.020739   0.017276
# min     0.037519   0.037601   0.057981   0.051731   0.008356   0.074137
# 25%     0.082017   0.094137   0.093000   0.088831   0.089687   0.092991
# 50%     0.098378   0.100864   0.103409   0.095816   0.097623   0.103802
# 75%     0.110685   0.104935   0.112902   0.107351   0.104588   0.118768
# max     0.132014   0.124568   0.134233   0.140706   0.126875   0.139726
#
# atoms        194        195        196        197        198        199  \
# count  36.000000  31.000000  35.000000  44.000000  34.000000  40.000000
# mean    0.106843   0.096552   0.113434   0.105531   0.103283   0.105183
# std     0.020289   0.021983   0.016895   0.015574   0.015557   0.019534
# min     0.083465   0.044513   0.081793   0.077662   0.072809   0.066042
# 25%     0.091092   0.083574   0.098948   0.094274   0.091270   0.091234
# 50%     0.101795   0.100467   0.110885   0.104451   0.101777   0.099300
# 75%     0.114526   0.110120   0.129791   0.112694   0.112972   0.125145
# max     0.185328   0.137587   0.143822   0.136819   0.135968   0.141567
#
# atoms        200        201        202        203        204        205  \
# count  31.000000  33.000000  26.000000  18.000000  21.000000  15.000000
# mean    0.109224   0.109112   0.107465   0.103198   0.108939   0.104949
# std     0.014216   0.014554   0.013672   0.011116   0.017383   0.016645
# min     0.090311   0.081592   0.076945   0.088735   0.067554   0.062736
# 25%     0.098342   0.096598   0.098272   0.093592   0.098001   0.095676
# 50%     0.107057   0.108002   0.104560   0.102329   0.109198   0.102253
# 75%     0.119950   0.118227   0.116104   0.108069   0.116981   0.115406
# max     0.137626   0.142236   0.139268   0.124533   0.136274   0.128317
#
# atoms       206        207        208       209        210       211  \
# count  9.000000  17.000000  16.000000  9.000000  12.000000  5.000000
# mean   0.104836   0.097705   0.103274  0.108159   0.104320  0.103777
# std    0.014189   0.013048   0.011688  0.020155   0.013924  0.023276
# min    0.085589   0.075318   0.078322  0.083944   0.087543  0.076077
# 25%    0.092813   0.088762   0.094327  0.101822   0.094437  0.088636
# 50%    0.103850   0.095022   0.104440  0.104555   0.100806  0.101610
# 75%    0.113146   0.106510   0.111980  0.107932   0.108260  0.117535
# max    0.126203   0.120101   0.121769  0.156535   0.134402  0.135027
#
# atoms        212        213       214       215       216       217       218  \
# count  24.000000  10.000000  5.000000  6.000000  4.000000  2.000000  5.000000
# mean    0.104254   0.109638  0.098796  0.102479  0.105912  0.090338  0.118712
# std     0.014514   0.008719  0.013050  0.005941  0.008510  0.005252  0.021437
# min     0.073821   0.092852  0.078366  0.093236  0.093630  0.086624  0.085874
# 25%     0.097111   0.105823  0.093791  0.099400  0.103815  0.088481  0.108960
# 50%     0.104758   0.109634  0.103352  0.103246  0.108566  0.090338  0.128267
# 75%     0.114518   0.113450  0.109212  0.106395  0.110663  0.092194  0.131503
# max     0.135615   0.125955  0.109259  0.109583  0.112885  0.094051  0.138957
#
# atoms       219       220       221       224       228
# count  4.000000  2.000000  2.000000  1.000000  2.000000
# mean   0.098197  0.104072  0.102404  0.114031  0.119855
# std    0.007294  0.019402  0.030391       NaN  0.013149
# min    0.089958  0.090353  0.080914  0.114031  0.110557
# 25%    0.093245  0.097213  0.091659  0.114031  0.115206
# 50%    0.098609  0.104072  0.102404  0.114031  0.119855
# 75%    0.103561  0.110932  0.113148  0.114031  0.124504
# max    0.105611  0.117792  0.123893  0.114031  0.129153
#
# [8 rows x 220 columns]

# %%
d2 = data.pivot_table(index = 'chembl_id', columns = 'atoms', values='DFT_HOMO_LUMO_GAP', aggfunc='mean')
display(d2.describe())
# Out:
# atoms       4         5         6         7         8          9          10   \
# count  5.000000  2.000000  3.000000  4.000000  6.000000  12.000000  22.000000
# mean   0.447196  0.401553  0.368677  0.414667  0.410994   0.394252   0.402533
# std    0.031505  0.049434  0.114535  0.042065  0.080050   0.050039   0.057758
# min    0.412357  0.366598  0.302398  0.372746  0.317170   0.289635   0.318633
# 25%    0.417526  0.384076  0.302550  0.388108  0.348460   0.373192   0.360203
# 50%    0.450644  0.401553  0.302702  0.408145  0.405551   0.398329   0.394861
# 75%    0.477711  0.419031  0.401816  0.434704  0.484190   0.422462   0.436096
# max    0.477742  0.436509  0.500931  0.469631  0.497859   0.479568   0.518844
#
# atoms        11         12         13          14          15          16   \
# count  32.000000  46.000000  75.000000  132.000000  225.000000  282.000000
# mean    0.381515   0.355655   0.346994    0.353515    0.341465    0.333863
# std     0.056967   0.051743   0.039326    0.051335    0.041264    0.041400
# min     0.277075   0.239593   0.258885    0.242761    0.250841    0.235578
# 25%     0.332055   0.327503   0.328380    0.312741    0.318210    0.308438
# 50%     0.386125   0.347398   0.343754    0.343444    0.333471    0.330410
# 75%     0.417523   0.390194   0.359402    0.392172    0.363138    0.355287
# max     0.498376   0.475581   0.493176    0.502128    0.487570    0.468122
#
# atoms         17          18          19          20           21   \
# count  404.000000  504.000000  607.000000  903.000000  1057.000000
# mean     0.338891    0.329184    0.323012    0.327532     0.325284
# std      0.045200    0.039384    0.037149    0.042894     0.042669
# min      0.255234    0.240778    0.231364    0.239249     0.218276
# 25%      0.308022    0.303037    0.298612    0.297133     0.294913
# 50%      0.330805    0.326023    0.316710    0.322558     0.318724
# 75%      0.357918    0.350553    0.340713    0.347504     0.350631
# max      0.498387    0.504956    0.462457    0.494255     0.491428
#
# atoms          22           23           24           25           26   \
# count  1200.000000  1477.000000  2055.000000  2267.000000  3023.000000
# mean      0.322771     0.323163     0.319700     0.316906     0.312790
# std       0.038570     0.042447     0.039868     0.037398     0.036529
# min       0.224708     0.226672     0.219055     0.193591     0.204508
# 25%       0.294559     0.294816     0.292275     0.292378     0.288398
# 50%       0.318140     0.314268     0.313250     0.313233     0.308066
# 75%       0.347411     0.345324     0.340891     0.337254     0.331069
# max       0.464924     0.493225     0.489237     0.509013     0.494384
#
# atoms          27           28           29           30           31   \
# count  3610.000000  4332.000000  4824.000000  5741.000000  6419.000000
# mean      0.310288     0.309110     0.307109     0.306070     0.305382
# std       0.035720     0.032845     0.034002     0.034175     0.031477
# min       0.184737     0.203321     0.208344     0.207431     0.211547
# 25%       0.287436     0.287893     0.284378     0.284236     0.285088
# 50%       0.305703     0.305645     0.303831     0.302025     0.301611
# 75%       0.328540     0.327176     0.325659     0.325437     0.324330
# max       0.487433     0.489845     0.476072     0.492571     0.485507
#
# atoms          32           33           34           35           36   \
# count  7060.000000  7777.000000  8523.000000  9085.000000  9816.000000
# mean      0.305059     0.303686     0.303584     0.302811     0.302922
# std       0.033351     0.033163     0.031614     0.031187     0.031234
# min       0.193924     0.149772     0.188901     0.177370     0.192731
# 25%       0.282983     0.281165     0.283000     0.282411     0.282035
# 50%       0.301593     0.300198     0.301191     0.299476     0.299617
# 75%       0.324925     0.323385     0.322929     0.321319     0.322422
# max       0.492758     0.475147     0.489666     0.474492     0.478556
#
# atoms           37            38            39            40            41   \
# count  11093.000000  11451.000000  12018.000000  12893.000000  13976.000000
# mean       0.302048      0.302180      0.302096      0.301567      0.301295
# std        0.030316      0.029903      0.029469      0.028867      0.028377
# min        0.200715      0.196691      0.197608      0.204095      0.187960
# 25%        0.282206      0.282650      0.282800      0.282572      0.282514
# 50%        0.299725      0.299657      0.299027      0.299233      0.299820
# 75%        0.320368      0.319950      0.319717      0.319031      0.318862
# max        0.482481      0.486908      0.493849      0.467646      0.485749
#
# atoms           42            43            44            45            46   \
# count  14699.000000  15226.000000  16205.000000  16142.000000  16781.000000
# mean       0.301284      0.301977      0.301218      0.300333      0.301379
# std        0.028373      0.028655      0.028312      0.027660      0.027846
# min        0.178991      0.193340      0.194790      0.185413      0.196212
# 25%        0.282701      0.282909      0.282467      0.282614      0.282975
# 50%        0.299098      0.300028      0.299852      0.298703      0.299437
# 75%        0.318666      0.319983      0.318976      0.316980      0.319464
# max        0.472099      0.485412      0.488136      0.487174      0.475636
#
# atoms           47            48   ...        179        180        181  \
# count  17161.000000  17696.000000  ...  56.000000  45.000000  45.000000
# mean       0.301021      0.301418  ...   0.320649   0.319989   0.314548
# std        0.027338      0.027610  ...   0.026652   0.030231   0.028489
# min        0.196845      0.145739  ...   0.227581   0.219563   0.188410
# 25%        0.282908      0.283358  ...   0.313845   0.312474   0.306349
# 50%        0.299254      0.299738  ...   0.321518   0.322208   0.316197
# 75%        0.318197      0.318378  ...   0.337064   0.337315   0.328718
# max        0.493323      0.457893  ...   0.363728   0.368459   0.358980
#
# atoms        182        183        184        185        186        187  \
# count  50.000000  48.000000  34.000000  40.000000  33.000000  43.000000
# mean    0.322952   0.315713   0.311804   0.326966   0.313766   0.324336
# std     0.029481   0.021984   0.025724   0.019960   0.037423   0.021547
# min     0.226586   0.270753   0.222628   0.261339   0.213227   0.269774
# 25%     0.311754   0.298409   0.302921   0.315614   0.301922   0.311059
# 50%     0.329127   0.318300   0.312470   0.327906   0.324101   0.329399
# 75%     0.342740   0.331421   0.324075   0.343451   0.332692   0.339552
# max     0.364122   0.362688   0.369813   0.357566   0.386612   0.361365
#
# atoms        188        189        190        191        192        193  \
# count  42.000000  25.000000  32.000000  56.000000  34.000000  43.000000
# mean    0.319134   0.328183   0.330212   0.323068   0.328364   0.336397
# std     0.029725   0.018234   0.021274   0.024333   0.026223   0.018536
# min     0.207310   0.269152   0.278888   0.263232   0.211680   0.301470
# 25%     0.302865   0.315947   0.317896   0.311870   0.326012   0.323264
# 50%     0.323669   0.333595   0.329720   0.323564   0.335847   0.335409
# 75%     0.335968   0.340425   0.347996   0.336015   0.340747   0.348293
# max     0.373155   0.351529   0.367258   0.376220   0.350647   0.376068
#
# atoms        194        195        196        197        198        199  \
# count  36.000000  31.000000  35.000000  44.000000  34.000000  40.000000
# mean    0.336841   0.324851   0.346742   0.338059   0.332173   0.335625
# std     0.026182   0.033526   0.016685   0.018020   0.023935   0.025078
# min     0.275256   0.245990   0.311104   0.283013   0.271875   0.276742
# 25%     0.327350   0.327584   0.336262   0.329151   0.321965   0.321720
# 50%     0.337851   0.332386   0.345223   0.336782   0.335810   0.334154
# 75%     0.350929   0.343480   0.359721   0.344138   0.346512   0.359745
# max     0.403516   0.374873   0.375980   0.381488   0.369196   0.389717
#
# atoms        200        201        202        203        204        205  \
# count  31.000000  33.000000  26.000000  18.000000  21.000000  15.000000
# mean    0.342510   0.341017   0.337353   0.339535   0.338591   0.339232
# std     0.013869   0.018657   0.015300   0.013467   0.022316   0.017544
# min     0.317571   0.291997   0.303992   0.319367   0.289247   0.309108
# 25%     0.333079   0.329489   0.328789   0.330607   0.325756   0.329503
# 50%     0.340392   0.341685   0.336167   0.337875   0.338961   0.340343
# 75%     0.352077   0.354603   0.346168   0.348853   0.351001   0.344194
# max     0.368360   0.374428   0.368191   0.363964   0.373198   0.385308
#
# atoms       206        207        208       209        210       211  \
# count  9.000000  17.000000  16.000000  9.000000  12.000000  5.000000
# mean   0.339200   0.333505   0.332147  0.348139   0.339594  0.341262
# std    0.016019   0.013847   0.019083  0.016437   0.014971  0.019199
# min    0.316066   0.303222   0.294998  0.325572   0.321329  0.308890
# 25%    0.326438   0.327829   0.323528  0.340738   0.328769  0.338276
# 50%    0.339773   0.333394   0.336752  0.347224   0.332574  0.352520
# 75%    0.352565   0.342006   0.347587  0.348206   0.351272  0.352882
# max    0.362660   0.357623   0.362767  0.386438   0.367883  0.353743
#
# atoms        212        213       214       215       216       217       218  \
# count  24.000000  10.000000  5.000000  6.000000  4.000000  2.000000  5.000000
# mean    0.348416   0.346264  0.348648  0.338363  0.330542  0.321036  0.355513
# std     0.010895   0.007918  0.012812  0.009389  0.018414  0.007204  0.025574
# min     0.327714   0.333100  0.328379  0.322664  0.310070  0.315943  0.314651
# 25%     0.342435   0.341970  0.347132  0.335425  0.319298  0.318489  0.347526
# 50%     0.348467   0.346548  0.348408  0.338515  0.329724  0.321036  0.365416
# 75%     0.358338   0.348678  0.358991  0.345564  0.340968  0.323583  0.371369
# max     0.364617   0.360800  0.360331  0.348175  0.352650  0.326130  0.378602
#
# atoms       219       220       221      224       228
# count  4.000000  2.000000  2.000000  1.00000  2.000000
# mean   0.321402  0.338057  0.350972  0.36233  0.363396
# std    0.005368  0.020626  0.045787      NaN  0.015823
# min    0.317306  0.323473  0.318595  0.36233  0.352207
# 25%    0.317445  0.330765  0.334784  0.36233  0.357802
# 50%    0.319777  0.338057  0.350972  0.36233  0.363396
# 75%    0.323734  0.345350  0.367160  0.36233  0.368990
# max    0.328747  0.352642  0.383348  0.36233  0.374584
#
# [8 rows x 220 columns]

# %% [markdown]
# ## QMUGs Curation

# %% [markdown]
# Objective: Create histogram plots or distribution plots of the HOMO-LUMO gap values from GFN2 and DFT columns (separately).
#
# To do this you can adjust the number of bins being calculated. What we are looking for are peaks present within the data as seen in the publications when plotting the number of compounds vs the GAP values.

# %%
# canonicalize smiles strings 
data['rdkit_smile'] = data['smiles'].apply(curate_data.base_smiles_from_smiles)

# %%
data['inchi_key'] = data['smiles'].apply(struct_utils.smiles_to_inchi_key)

# %%
data['compound_id'] = data['inchi_key']

# %%
data.head(6)

# %%
data.to_csv("qmugs_rdkit_smiles.csv", index = False)

# %%
from rdkit import Chem
from rdkit.Chem import Draw
from itertools import islice

molecules = [Chem.MolFromSmiles(smiles) for smiles in islice(data['smiles'], 9)]

Draw.MolsToGridImage(molecules)

# %%
# check if there is na value
na_value1 = data["GFN2_HOMO_LUMO_GAP"].isna().any()
na_value2 = data["DFT_HOMO_LUMO_GAP"].isna().any()
print(na_value1, na_value2)

# %%
# look at length of dataset and duplicates.
print('Name duplicates:', data['compound_id'].duplicated().sum())
print('SMILES duplicates:', data.smiles.duplicated().sum())
print('Shape:', data.shape)

# %%
# column: Response values column
column = 'GFN2_HOMO_LUMO_GAP'

# tolerance: Percentage of individual respsonse values allowed to be different 
# from the average to be included in averaging
tolerance = 10

# list_bad_duplicates: Print structures with bad duplicates
list_bad_duplicates = 'Yes'

# max_std: Maximum allowed standard deviation for computed average response value
# NOTE: In this example, we set this value very high to disable this feature
max_std = 100000

# compound_id: Compound ID column
compound_id = 'compound_id'

# smiles_col: SMILES column
smiles_col = 'rdkit_smile'

# call the method `average_and_remove_duplicates` which changes the data and returns
# the new object as curated_df, in this case
 

curated_df = curate_data.average_and_remove_duplicates(column, 
                                                       tolerance, 
                                                       list_bad_duplicates, 
                                                       data, 
                                                       max_std, 
                                                       compound_id = compound_id, 
                                                       smiles_col = smiles_col)

# %%
# column: Response values column
column = 'DFT_HOMO_LUMO_GAP'

# tolerance: Percentage of individual respsonse values allowed to be different 
# from the average to be included in averaging
tolerance = 10

# list_bad_duplicates: Print structures with bad duplicates
list_bad_duplicates = 'Yes'

# max_std: Maximum allowed standard deviation for computed average response value
# NOTE: In this example, we set this value very high to disable this feature
max_std = 100000

# compound_id: Compound ID column
compound_id = 'compound_id'

# smiles_col: SMILES column
smiles_col = 'rdkit_smile'

# call the method `average_and_remove_duplicates` which changes the data and returns
# the new object as curated_df, in this case
 

curated_df = curate_data.average_and_remove_duplicates(column, 
                                                       tolerance, 
                                                       list_bad_duplicates, 
                                                       data, 
                                                       max_std, 
                                                       compound_id = compound_id, 
                                                       smiles_col = smiles_col)

# %%
curated_df = pd.read_csv("curated_qmugs_data.csv", sep=',', header=0)

# %%
curated_df.shape

# %%
curated_df.head()

# %%
curated_df.to_csv("curated_qmugs_data.csv", index=False)

# %% [markdown]
# ## Visualize distribution of molecular weights

# %%
curated_df = pd.read_csv("columbia_select_qmugs_data_selected.csv", sep=',')

# %%
plot_df = curated_df
plot_df = plot_df.sort_values(by = 'mw')
plot_df = plot_df.reset_index(drop = True)
plot_df = plot_df.reset_index()

fig,ax = plt.subplots(1,2, figsize = (15,5))
plot_df.plot(kind = 'scatter', x = 'index', y = 'mw', color = pal[0], ax = ax[0])
plot_df.plot(kind = 'hist', x = "index", y = "mw", color = pal[0], ax = ax[1])
fig.suptitle("Distribution of molecular weights in QMUGs dataset");

# %%
# examine standard values and GFN2 HOMO-LUMO GAP values PER type
data_types = curated_df.pivot_table(index = 'compound_id', columns = 'heavy_atoms', values='GFN2_HOMO_LUMO_GAP', aggfunc='mean')
display(data_types.describe())
data_types.hist(figsize=(8,8))
plt.show()

# %%
# examine standard values and DFT HOMO-LUMO GAP values PER type
data_types = data.pivot_table(index = 'compound_id', columns = 'chembl_id', values='DFT_HOMO_LUMO_GAP', aggfunc='mean')
display(data_types.describe())
data_types.hist(figsize=(8,8))
plt.show()

# %% [markdown]
# ## Compare HOMO-LUMO Gap Values across GFN2 and DFT

# %%
curated_df = pd.read_csv("curated_qmugs_data.csv", sep = ',', header=0)

# %%
fig, ax = plt.subplots(figsize = (5,5))
sns.distplot(curated_df.GFN2_HOMO_LUMO_GAP, ax=ax, color = "green", label='GFN2_HOMO_LUMO_GAP')
sns.distplot(curated_df.DFT_HOMO_LUMO_GAP, ax=ax, color = "orange", label='DFT_HOMO_LUMO_GAP')
ax.legend()
plt.show()

# %%
# Determine the minimum and maximum values of the overlap range
overlap_min = max(curated_df['GFN2_HOMO_LUMO_GAP'].min(), curated_df['DFT_HOMO_LUMO_GAP'].min())
overlap_max = min(curated_df['GFN2_HOMO_LUMO_GAP'].max(), curated_df['DFT_HOMO_LUMO_GAP'].max())

plt.figure(figsize=(5, 5))

# Plot the histograms for gfn2 and dft values within the overlap range
sns.histplot(curated_df[(curated_df['GFN2_HOMO_LUMO_GAP'] >= overlap_min) & (curated_df['GFN2_HOMO_LUMO_GAP'] <= overlap_max)]['GFN2_HOMO_LUMO_GAP'], 
             kde=True, bins=30, label='GFN2', color='green', alpha=0.5)

sns.histplot(curated_df[(curated_df['DFT_HOMO_LUMO_GAP'] >= overlap_min) & (curated_df['DFT_HOMO_LUMO_GAP'] <= overlap_max)]['DFT_HOMO_LUMO_GAP'], 
             kde=True, bins=30, label='DFT', color='orange', alpha=0.5)

plt.title('Histogram of Overlapping Range for GFN2 and DFT gap values')
plt.legend()
plt.show()

# %%
# adjust the region to capture the overlap of two gap values
overlap_start = 0.178
overlap_end = 0.22

plt.figure(figsize=(13, 13))

# Plot the histograms for gfn2 and dft values within the overlap range
sns.histplot(curated_df[(curated_df['GFN2_HOMO_LUMO_GAP'] >= overlap_start) & (curated_df['GFN2_HOMO_LUMO_GAP'] <= overlap_end)]['GFN2_HOMO_LUMO_GAP'], 
             kde=True, bins=30, label='GFN2', color='green', alpha=0.5)

sns.histplot(curated_df[(curated_df['DFT_HOMO_LUMO_GAP'] >= overlap_start) & (curated_df['DFT_HOMO_LUMO_GAP'] <= overlap_end)]['DFT_HOMO_LUMO_GAP'], 
             kde=True, bins=30, label='DFT', color='orange', alpha=0.5)

plt.title('Histogram of Overlapping Range for GFN2 and DFT gap values')
plt.legend()
plt.show()

# %%
overlap = curated_df[(curated_df['GFN2_HOMO_LUMO_GAP'] >= overlap_start) & (curated_df['GFN2_HOMO_LUMO_GAP'] <= overlap_end)]['GFN2_HOMO_LUMO_GAP']
overlap.describe()

# %%
fig, ax = plt.subplots(1,1,figsize = (5,5))
sns.distplot(curated_df.GFN2_HOMO_LUMO_GAP, ax=ax, color = "green")
plt.title('Histogram of for GFN2 gap values')
plt.show()

# %%
fig, ax = plt.subplots(1,1,figsize = (5,5))
sns.distplot(curated_df.DFT_HOMO_LUMO_GAP, ax=ax, color = "orange")
plt.title('Histogram for DFT gap values')
plt.show()

# %%
dp.diversity_plots(dset_key='curated_qmugs_data.csv',
                   datastore=False, 
                   id_col ='compound_id', 
                   smiles_col = 'rdkit_smile', 
                   is_base_smiles=True, 
                   response_col = 'mw')

# %% [markdown]
# ## Number of Atoms and Gap Values

# %% [markdown]
# Focus on looking at the number of rings, heavy atom count, and molecular weight.
#
# Determine the different thresholds (25%, 50%, 75%, median, average, etc.) of these different molecule properties and make separate dataframes. You can then plot these groupings in similar plots as you had made for the entirety of the dataset to determine if there are trends we are seeing depending on the gap values. Make sure your labels as you prepare the dataframes are easy to follow so you do not get confused, the number of groupings you are working with it is easy to do.

# %% [markdown]
# ### Seperating numbers of atoms each compound has by quantiles into smaller dataset accordingly.

# %%
curated_df.describe()

# %%
atom25_df = curated_df[curated_df["atoms"] <= 43]
atom50_df = curated_df[(curated_df["atoms"] > 43) & (curated_df["atoms"] <= 53)]
atom75_df = curated_df[(curated_df["atoms"] > 53) & (curated_df["atoms"] <= 63)]
atom100_df = curated_df[curated_df["atoms"] > 63 ]
atom_average_df = curated_df[curated_df["atoms"] == 55.223975 ]

# %%
# check to see if filter works
atom50_df.head()

# %%
atom_average_df.head()

# %%
atom25_df = atom25_df[["chembl_id","compound_id","atoms","GFN2_HOMO_LUMO_GAP","DFT_HOMO_LUMO_GAP","rdkit_smile"]]
atom50_df = atom50_df[["chembl_id","compound_id","atoms","GFN2_HOMO_LUMO_GAP","DFT_HOMO_LUMO_GAP","rdkit_smile"]]
atom75_df = atom75_df[["chembl_id","compound_id","atoms","GFN2_HOMO_LUMO_GAP","DFT_HOMO_LUMO_GAP","rdkit_smile"]]
atom100_df = atom100_df[["chembl_id","compound_id","atoms","GFN2_HOMO_LUMO_GAP","DFT_HOMO_LUMO_GAP","rdkit_smile"]]
atom_average_df = atom_average_df[["chembl_id","compound_id","atoms","GFN2_HOMO_LUMO_GAP","DFT_HOMO_LUMO_GAP","rdkit_smile"]]

# %%
atom50_df.head()

# %% [markdown]
# ### Plots regarding to atoms and gap values

# %% [markdown]
# #### atoms, 25 percentile

# %%
# find distribution of different atom numbers
atom25_df.atoms.value_counts().plot(kind='bar', figsize = (8,8))

# %%
# examine GFN2 HOMO LUMO GAP Value PER Compound Id
atom25_types = atom25_df.pivot_table(index = 'compound_id', columns = 'atoms', values='GFN2_HOMO_LUMO_GAP', aggfunc='mean')
atom25_types.hist(figsize=(13,13));

# %%
# scatter plots
sns.scatterplot(x = 'atoms', y='GFN2_HOMO_LUMO_GAP', data = atom25_df, label= 'GFN2', marker = 'o')
# Plotting dft values
sns.scatterplot(x = 'atoms', y='DFT_HOMO_LUMO_GAP', data = atom25_df, label='DFT', marker='x')

plt.title('GFN2 and DFT values vs. Number of Atoms')
plt.xlabel('Number of Atoms')
plt.ylabel('Values')
plt.legend()
plt.show()

# %%
# Compute the correlation matrix
corr_matrix = atom25_df[['atoms', 'GFN2_HOMO_LUMO_GAP']].corr()

# Plot the heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Heatmap of Correlation between number of atoms and gfn2 gap values')
plt.show()

# %%
# Histogram for gfn2 values
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.histplot(atom25_df['GFN2_HOMO_LUMO_GAP'], kde=True, bins=30)
plt.title('Histogram for GFN2 gap values')

# Histogram for dft values
plt.subplot(1, 2, 2)
sns.histplot(atom25_df['DFT_HOMO_LUMO_GAP'], kde=True, bins=30)
plt.title('Histogram for DFT gap values')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### atoms, 50 percentile

# %%
# find distribution of different atom numbers
atom50_df.atoms.value_counts().plot(kind='bar', figsize = (8,8))

# %%
# examine GFN2 HOMO LUMO GAP Value PER Compound Id
atom50_types = atom50_df.pivot_table(index = 'compound_id', columns = 'atoms', values='GFN2_HOMO_LUMO_GAP', aggfunc='mean')
atom50_types.hist(figsize=(13,13));

# %%
# scatter plots
sns.scatterplot(x = 'atoms', y='GFN2_HOMO_LUMO_GAP', data = atom50_df, label= 'GFN2', marker = 'o')
# Plotting dft values
sns.scatterplot(x = 'atoms', y='DFT_HOMO_LUMO_GAP', data = atom50_df, label='DFT', marker='x')

plt.title('GFN2 and DFT values vs. Number of Atoms')
plt.xlabel('Number of Atoms')
plt.ylabel('Values')
plt.legend()
plt.show()

# %%
# Compute the correlation matrix
corr_matrix = atom50_df[['atoms', 'GFN2_HOMO_LUMO_GAP']].corr()

# Plot the heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Heatmap of Correlation between number of atoms and gfn2 gap values')
plt.show()

# %%
# Histogram for gfn2 values
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.histplot(atom50_df['GFN2_HOMO_LUMO_GAP'], kde=True, bins=30)
plt.title('Histogram for GFN2 gap values')

# Histogram for dft values
plt.subplot(1, 2, 2)
sns.histplot(atom50_df['DFT_HOMO_LUMO_GAP'], kde=True, bins=30)
plt.title('Histogram for DFT gap values')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### atoms, 75 percentile

# %%
# find distribution of different atom numbers
atom75_df.atoms.value_counts().plot(kind='bar', figsize = (8,8))

# %%
# examine GFN2 HOMO LUMO GAP Value PER Compound Id
atom75_types = atom75_df.pivot_table(index = 'compound_id', columns = 'atoms', values='GFN2_HOMO_LUMO_GAP', aggfunc='mean')
atom75_types.hist(figsize=(13,13));

# %%
# scatter plots
sns.scatterplot(x = 'atoms', y='GFN2_HOMO_LUMO_GAP', data = atom75_df, label= 'GFN2', marker = 'o')
# Plotting dft values
sns.scatterplot(x = 'atoms', y='DFT_HOMO_LUMO_GAP', data = atom75_df, label='DFT', marker='x')

plt.title('GFN2 and DFT values vs. Number of Atoms')
plt.xlabel('Number of Atoms')
plt.ylabel('Values')
plt.legend()
plt.show()

# %%
# Compute the correlation matrix
corr_matrix = atom75_df[['atoms', 'GFN2_HOMO_LUMO_GAP']].corr()

# Plot the heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Heatmap of Correlation between number of atoms and gfn2 gap values')
plt.show()

# %%
# Histogram for gfn2 values
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.histplot(atom75_df['GFN2_HOMO_LUMO_GAP'], kde=True, bins=30)
plt.title('Histogram for GFN2 gap values')

# Histogram for dft values
plt.subplot(1, 2, 2)
sns.histplot(atom75_df['DFT_HOMO_LUMO_GAP'], kde=True, bins=30)
plt.title('Histogram for DFT gap values')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### atoms, 100 percentile

# %%
# find distribution of different atom numbers
atom100_df.atoms.value_counts().plot(kind='bar', figsize = (8,8))

# %%
# examine GFN2 HOMO LUMO GAP Value PER Compound Id
atom100_types = atom75_df.pivot_table(index = 'compound_id', columns = 'atoms', values='GFN2_HOMO_LUMO_GAP', aggfunc='mean')
atom100_types.hist(figsize=(13,13));

# %%
# scatter plots
sns.scatterplot(x = 'atoms', y='GFN2_HOMO_LUMO_GAP', data = atom100_df, label= 'GFN2', marker = 'o')
# Plotting dft values
sns.scatterplot(x = 'atoms', y='DFT_HOMO_LUMO_GAP', data = atom100_df, label='DFT', marker='x')

plt.title('GFN2 and DFT values vs. Number of Atoms')
plt.xlabel('Number of Atoms')
plt.ylabel('Values')
plt.legend()
plt.show()

# %%
# Compute the correlation matrix
corr_matrix = atom100_df[['atoms', 'GFN2_HOMO_LUMO_GAP']].corr()

# Plot the heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Heatmap of Correlation between number of atoms and gfn2 gap values')
plt.show()

# %%
# Histogram for gfn2 values
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.histplot(atom100_df['GFN2_HOMO_LUMO_GAP'], kde=True, bins=30)
plt.title('Histogram for GFN2 gap values')

# Histogram for dft values
plt.subplot(1, 2, 2)
sns.histplot(atom100_df['DFT_HOMO_LUMO_GAP'], kde=True, bins=30)
plt.title('Histogram for DFT gap values')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### atoms, average

# %%
# plot each quantile together to see if there are shifts.

# %% [markdown]
# ## Rings and gap values

# %% [markdown]
# #### rings

# %%
ring25_df = curated_df[curated_df["rings"] <= 3]
ring50_df = curated_df[(curated_df["rings"] > 3) & (curated_df["rings"] <= 4)]
ring75_df = curated_df[(curated_df["rings"] > 4) & (curated_df["rings"] <= 5)]
ring100_df = curated_df[curated_df["rings"] > 5 ]
ring_average_df = curated_df[curated_df["rings"] == 3.801509 ]

# %%
# check to see if filter works
ring25_df.head()
# Out:
#       chembl_id  conf_id                                             smiles  \
# 1    CHEMBL1000  conf_00  [H]OC(=O)C([H])([H])OC([H])([H])C([H])([H])N1C...
# 2   CHEMBL10000  conf_00  [H]c1c([H])c(N([H])c2nc3c([H])c([H])c([H])c([H...
# 3  CHEMBL100003  conf_00  [H]O/C(OC([H])([H])[H])=C1\C(C([H])([H])[H])=N...
# 4  CHEMBL100004  conf_00  [H]O/C(OC([H])([H])C([H])([H])[H])=C1\C(C([H])...
# 6  CHEMBL100010  conf_01  [H]c1c([H])c([H])c(C2=C(C(=O)OC([H])([H])[H])[...
#
#            mw  atoms  heavy_atoms  heteroatoms  rotatable_bonds  \
# 1  388.155370     52           27            6                8
# 2  363.970876     28           19            5                2
# 3  281.162708     43           20            5               11
# 4  375.150429     51           26            6               12
# 6  242.130680     36           18            2                3
#
#    stereocenters  rings  hbond_acceptors  hbond_donors  \
# 1              1      3                5             1
# 2              0      3                4             1
# 3              1      1                5             1
# 4              1      2                6             1
# 6              2      3                2             0
#
#    significant_negative_wavenumbers  nonunique_smiles  GFN2_TOTAL_ENERGY  \
# 1                             False             False         -80.315048
# 2                             False             False         -52.393036
# 3                             False             False         -63.044635
# 4                             False             False         -78.009245
# 6                             False             False         -51.591222
#
#    GFN2_ATOMIC_ENERGY  GFN2_FORMATION_ENERGY  GFN2_TOTAL_ENTHALPY  \
# 1          -68.493287             -11.821760           -79.870590
# 2          -45.173987              -7.219049           -52.180530
# 3          -53.625801              -9.418834           -62.664873
# 4          -66.525705             -11.483539           -77.573112
# 6          -43.310646              -8.280577           -51.275771
#
#    GFN2_TOTAL_FREE_ENERGY  GFN2_DIPOLE_X  GFN2_DIPOLE_Y  GFN2_DIPOLE_Z  \
# 1              -79.950811          2.379         -3.195          4.509
# 2              -52.241437         -1.362          0.292          0.020
# 3              -62.740190         -4.793         -0.892          0.956
# 4              -77.659095         -6.628          0.168          2.814
# 6              -51.336977         -1.431         -1.052          1.317
#
#    GFN2_DIPOLE_TOT  GFN2_QUADRUPOLE_XX  GFN2_QUADRUPOLE_XY  \
# 1            6.017               5.337             -25.657
# 2            1.394             -14.034             -36.284
# 3            4.970              29.019               4.478
# 4            7.203              13.223              -5.233
# 6            2.212               0.485              -4.154
#
#    GFN2_QUADRUPOLE_YY  GFN2_QUADRUPOLE_XZ  GFN2_QUADRUPOLE_yz  \
# 1              -4.502              -1.798              11.798
# 2               0.606              -4.581              -2.685
# 3              -8.898             -11.014              -3.925
# 4              -9.217              -3.183               3.113
# 6               3.922               3.976               1.385
#
#    GFN2_QUADRUPOLE_ZZ  GFN2_ROT_CONSTANT_A  GFN2_ROT_CONSTANT_B  \
# 1              -0.835             0.009034             0.002935
# 2              13.428             0.027951             0.002706
# 3             -20.121             0.017387             0.007241
# 4              -4.005             0.012093             0.002612
# 6              -4.407             0.019705             0.012370
#
#    GFN2_ROT_CONSTANT_C  GFN2_ENTHALPY_VIB  GFN2_ENTHALPY_ROT  \
# 1             0.002678          14005.394            888.752
# 2             0.002467           8093.824            888.752
# 3             0.006572          12871.935            888.752
# 4             0.002261          15834.103            888.752
# 6             0.008719           8477.505            888.752
#
#    GFN2_ENTHALPY_TRANSL  GFN2_ENTHALPY_TOT  GFN2_HEAT_CAPACITY_VIB  \
# 1              1481.254          16375.401                  91.382
# 2              1481.254          10463.830                  54.575
# 3              1481.254          15241.942                  78.134
# 4              1481.254          18204.109                  97.510
# 6              1481.254          10847.511                  56.574
#
#    GFN2_HEAT_CAPACITY_ROT  GFN2_HEAT_CAPACITY_TRANSL  GFN2_HEAT_CAPACITY_TOT  \
# 1                   2.981                      4.968                  99.331
# 2                   2.981                      4.968                  62.524
# 3                   2.981                      4.968                  86.083
# 4                   2.981                      4.968                 105.459
# 6                   2.981                      4.968                  64.523
#
#    GFN2_ENTROPY_VIB  GFN2_ENTROPY_ROT  GFN2_ENTROPY_TRANSL  GFN2_ENTROPY_TOT  \
# 1            88.721            36.373               43.746           168.840
# 2            49.224            35.414               43.551           128.189
# 3            81.802            33.934               42.782           158.518
# 4           100.957            36.367               43.642           180.966
# 6            53.486            32.996               42.337           128.820
#
#    GFN2_HOMO_ENERGY  GFN2_LUMO_ENERGY  GFN2_HOMO_LUMO_GAP  GFN2_FERMI_LEVEL  \
# 1         -0.352364         -0.237194            0.115170         -0.294779
# 2         -0.392061         -0.285465            0.106596         -0.338763
# 3         -0.350243         -0.270147            0.080096         -0.310195
# 4         -0.353439         -0.283588            0.069851         -0.318514
# 6         -0.382563         -0.257754            0.124809         -0.320158
#
#    GFN2_DISPERSION_COEFFICIENT_MOLECULAR  GFN2_POLARIZABILITY_MOLECULAR  \
# 1                           31094.695246                     272.494292
# 2                           15494.797760                     200.975607
# 3                           16751.288449                     195.140373
# 4                           29419.012760                     265.673033
# 6                           13562.233738                     179.607696
#
#    DFT_TOTAL_ENERGY  DFT_ATOMIC_ENERGY  DFT_FORMATION_ENERGY  DFT_DIPOLE_X  \
# 1      -1609.322700       -1600.285930             -9.036771      2.142420
# 2      -1095.832353       -1090.450449             -5.381904     -0.349732
# 3       -940.100277        -932.957960             -7.142316     -4.986451
# 4      -1529.710027       -1520.925372             -8.784655     -6.228561
# 6       -770.202248        -763.767820             -6.434427     -1.417204
#
#    DFT_DIPOLE_Y  DFT_DIPOLE_Z  DFT_DIPOLE_TOT  DFT_ROT_CONSTANT_A  \
# 1     -2.785717      4.253252        5.517276            0.008840
# 2      0.940967      0.138212        1.013328            0.027875
# 3     -0.869709      2.092616        5.477238            0.017294
# 4      1.164321      2.815141        6.933659            0.012092
# 6     -0.444106      0.700524        1.642081            0.019608
#
#    DFT_ROT_CONSTANT_B  DFT_ROT_CONSTANT_C  DFT_XC_ENERGY  \
# 1            0.002865            0.002636    -132.809395
# 2            0.002163            0.002008     -91.786777
# 3            0.007228            0.006575     -90.337873
# 4            0.002591            0.002246    -128.312742
# 6            0.012267            0.008648     -76.098435
#
#    DFT_NUCLEAR_REPULSION_ENERGY  DFT_ONE_ELECTRON_ENERGY  \
# 1                   2659.135307             -7485.087002
# 2                   1456.814354             -4495.141648
# 3                   1704.654877             -4667.691840
# 4                   2455.485098             -6971.678300
# 6                   1340.771960             -3707.556233
#
#    DFT_TWO_ELECTRON_ENERGY  DFT_HOMO_ENERGY  DFT_LUMO_ENERGY  \
# 1              3349.488535        -0.296513         0.044311
# 2              2034.299009        -0.292609         0.000486
# 3              2113.309805        -0.263692         0.011718
# 4              3114.833616        -0.274412        -0.002106
# 6              1672.709355        -0.306396         0.030075
#
#    DFT_HOMO_LUMO_GAP                                        rdkit_smile  \
# 1           0.340824   O=C(O)COCCN1CCN([C@@H](c2ccccc2)c2ccc(Cl)cc2)CC1
# 2           0.293095                     O=c1oc(Nc2ccc(I)cc2)nc2ccccc12
# 3           0.275410        CCC[C@@H]1C(C(=O)OCC)=C(C)N=C(C)/C1=C(\O)OC
# 4           0.272307  CCO/C(O)=C1/C(C)=NC(C)=C(C(=O)OCCSc2ccccc2)[C@...
# 6           0.336471            COC(=O)C1=C(c2ccccc2)C[C@@H]2CC[C@H]1C2
#
#                    compound_id  VALUE_NUM_mean  VALUE_NUM_std  Perc_Var  \
# 1  ZKLPARSLTMPFCP-NRFANRHFSA-N        0.333456       0.006397  2.209649
# 2  KXLZEFPIBPQEAU-UHFFFAOYSA-N        0.289124       0.003439  1.373521
# 3  FCFUFMMLEUYHMD-CDZMIXDFSA-N        0.282891       0.007237  2.644696
# 4  CUHAMGYOMBKPLA-BQOWYSNXSA-N        0.272592       0.003115  0.104604
# 6  BXNXEXWOZMNHST-YPMHNXCESA-N        0.337342       0.002364  0.258233
#
#    Remove_BadDuplicate
# 1                    0
# 2                    0
# 3                    0
# 4                    0
# 6                    0

# %%
ring25_df = ring25_df[["chembl_id","compound_id","rings","GFN2_HOMO_LUMO_GAP","DFT_HOMO_LUMO_GAP","rdkit_smile"]]
ring50_df = ring50_df[["chembl_id","compound_id","rings","GFN2_HOMO_LUMO_GAP","DFT_HOMO_LUMO_GAP","rdkit_smile"]]
ring75_df = ring75_df[["chembl_id","compound_id","rings","GFN2_HOMO_LUMO_GAP","DFT_HOMO_LUMO_GAP","rdkit_smile"]]
ring100_df = ring100_df[["chembl_id","compound_id","rings","GFN2_HOMO_LUMO_GAP","DFT_HOMO_LUMO_GAP","rdkit_smile"]]
ring_average_df = ring_average_df[["chembl_id","compound_id","rings","GFN2_HOMO_LUMO_GAP","DFT_HOMO_LUMO_GAP","rdkit_smile"]]

# %% [markdown]
# #### rings, 25 percentile

# %%
# find distribution of different ring numbers
ring25_df.rings.value_counts().plot(kind='bar', figsize = (8,8))
# Out:
# <AxesSubplot:>

# %%
# examine GFN2 HOMO LUMO GAP Value PER Compound Id
ring25_types = ring25_df.pivot_table(index = 'compound_id', columns = 'rings', values='GFN2_HOMO_LUMO_GAP', aggfunc='mean')
ring25_types.hist(figsize=(13,13));

# %%
# scatter plots
sns.scatterplot(x = 'rings', y='GFN2_HOMO_LUMO_GAP', data = ring25_df, label= 'GFN2', marker = 'o')
# Plotting dft values
sns.scatterplot(x = 'rings', y='DFT_HOMO_LUMO_GAP', data = ring25_df, label='DFT', marker='x')

plt.title('GFN2 and DFT values vs. Number of Rings')
plt.xlabel('Number of Rings')
plt.ylabel('Values')
plt.legend()
plt.show()

# %%
# Compute the correlation matrix
corr_matrix = ring25_df[['rings', 'GFN2_HOMO_LUMO_GAP']].corr()

# Plot the heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Heatmap of Correlation between number of rings and gfn2 gap values')
plt.show()

# %%
# Histogram for gfn2 values
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.histplot(ring25_df['GFN2_HOMO_LUMO_GAP'], kde=True, bins=30)
plt.title('Histogram for GFN2 gap values')

# Histogram for dft values
plt.subplot(1, 2, 2)
sns.histplot(ring25_df['DFT_HOMO_LUMO_GAP'], kde=True, bins=30)
plt.title('Histogram for DFT gap values')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### rings, 50 percentile

# %%
# find distribution of different ring numbers
ring50_df.rings.value_counts().plot(kind='bar', figsize = (8,8))
# Out:
# <AxesSubplot:>

# %%
# examine GFN2 HOMO LUMO GAP Value PER Compound Id
ring50_types = ring50_df.pivot_table(index = 'compound_id', columns = 'rings', values='GFN2_HOMO_LUMO_GAP', aggfunc='mean')
ring50_types.hist(figsize=(13,13));

# %%
# scatter plots
sns.scatterplot(x = 'rings', y='GFN2_HOMO_LUMO_GAP', data = ring50_df, label= 'GFN2', marker = 'o')
# Plotting dft values
sns.scatterplot(x = 'rings', y='DFT_HOMO_LUMO_GAP', data = ring50_df, label='DFT', marker='x')

plt.title('GFN2 and DFT values vs. Number of Rings')
plt.xlabel('Number of Rings')
plt.ylabel('Values')
plt.legend()
plt.show()

# %%
# Compute the correlation matrix
corr_matrix = ring50_df[['rings', 'GFN2_HOMO_LUMO_GAP']].corr()

# Plot the heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Heatmap of Correlation between number of rings and gfn2 gap values')
plt.show()

# %%
# Histogram for gfn2 values
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.histplot(ring50_df['GFN2_HOMO_LUMO_GAP'], kde=True, bins=30)
plt.title('Histogram for GFN2 gap values')

# Histogram for dft values
plt.subplot(1, 2, 2)
sns.histplot(ring50_df['DFT_HOMO_LUMO_GAP'], kde=True, bins=30)
plt.title('Histogram for DFT gap values')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### rings, 75 percentile

# %%
# find distribution of different ring numbers
ring75_df.rings.value_counts().plot(kind='bar', figsize = (8,8))
# Out:
# <AxesSubplot:>

# %%
# examine GFN2 HOMO LUMO GAP Value PER Compound Id
ring75_types = ring75_df.pivot_table(index = 'compound_id', columns = 'rings', values='GFN2_HOMO_LUMO_GAP', aggfunc='mean')
ring75_types.hist(figsize=(13,13));

# %%
# scatter plots
sns.scatterplot(x = 'rings', y='GFN2_HOMO_LUMO_GAP', data = ring75_df, label= 'GFN2', marker = 'o')
# Plotting dft values
sns.scatterplot(x = 'rings', y='DFT_HOMO_LUMO_GAP', data = ring75_df, label='DFT', marker='x')

plt.title('GFN2 and DFT values vs. Number of Rings')
plt.xlabel('Number of Rings')
plt.ylabel('Values')
plt.legend()
plt.show()

# %%
# Compute the correlation matrix
corr_matrix = ring100_df[['rings', 'GFN2_HOMO_LUMO_GAP']].corr()

# Plot the heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Heatmap of Correlation between number of rings and gfn2 gap values')
plt.show()

# %%
# Histogram for gfn2 values
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.histplot(ring75_df['GFN2_HOMO_LUMO_GAP'], kde=True, bins=30)
plt.title('Histogram for GFN2 gap values')

# Histogram for dft values
plt.subplot(1, 2, 2)
sns.histplot(ring75_df['DFT_HOMO_LUMO_GAP'], kde=True, bins=30)
plt.title('Histogram for DFT gap values')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### rings, 100 percentile

# %%
# find distribution of different ring numbers
ring100_df.rings.value_counts().plot(kind='bar', figsize = (8,8))
# Out:
# <AxesSubplot:>

# %%
# examine GFN2 HOMO LUMO GAP Value PER Compound Id
ring100_types = ring100_df.pivot_table(index = 'compound_id', columns = 'rings', values='GFN2_HOMO_LUMO_GAP', aggfunc='mean')
ring100_types.hist(figsize=(13,13));

# %%
# scatter plots
sns.scatterplot(x = 'rings', y='GFN2_HOMO_LUMO_GAP', data = ring100_df, label= 'GFN2', marker = 'o')
# Plotting dft values
sns.scatterplot(x = 'rings', y='DFT_HOMO_LUMO_GAP', data = ring100_df, label='DFT', marker='x')

plt.title('GFN2 and DFT values vs. Number of Rings')
plt.xlabel('Number of Rings')
plt.ylabel('Values')
plt.legend()
plt.show()

# %%
# Compute the correlation matrix
corr_matrix = ring100_df[['rings', 'GFN2_HOMO_LUMO_GAP']].corr()

# Plot the heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Heatmap of Correlation between number of rings and gfn2 gap values')
plt.show()

# %%
# Histogram for gfn2 values
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.histplot(ring100_df['GFN2_HOMO_LUMO_GAP'], kde=True, bins=30)
plt.title('Histogram for GFN2 gap values')

# Histogram for dft values
plt.subplot(1, 2, 2)
sns.histplot(ring100_df['DFT_HOMO_LUMO_GAP'], kde=True, bins=30)
plt.title('Histogram for DFT gap values')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### rings, average

# %%
# find distribution of average rings
ring_average_df.rings.value_counts().plot(kind='bar', figsize = (8,8))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-32-c96008457e68> in <module>
#       1 # find distribution of average rings
# ----> 2 ring_average_df.rings.value_counts().plot(kind='bar', figsize = (8,8))
#
# ~/atomsci/lib/python3.8/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     970                     data.columns = label_name
#     971
# --> 972         return plot_backend.plot(data, kind=kind, **kwargs)
#     973
#     974     __call__.__doc__ = __doc__
#
# ~/atomsci/lib/python3.8/site-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71     plot_obj.generate()
#      72     plot_obj.draw()
#      73     return plot_obj.result
#
# ~/atomsci/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py in generate(self)
#     293         for ax in self.axes:
#     294             self._post_plot_logic_common(ax, self.data)
# --> 295             self._post_plot_logic(ax, self.data)
#     296
#     297     def _args_adjust(self):
#
# ~/atomsci/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py in _post_plot_logic(self, ax, data)
#    1526         name = self._get_index_name()
#    1527
# -> 1528         s_edge = self.ax_pos[0] - 0.25 + self.lim_offset
#    1529         e_edge = self.ax_pos[-1] + 0.25 + self.bar_width + self.lim_offset
#    1530
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %% [markdown]
# ## Heavy atoms counts and gap values

# %% [markdown]
# #### heavy atoms

# %%
heavy_atom25_df = curated_df[curated_df["heavy_atoms"] <= 20]
heavy_atom50_df = curated_df[(curated_df["heavy_atoms"] > 20) & (curated_df["heavy_atoms"] <= 30)]
heavy_atom75_df = curated_df[(curated_df["heavy_atoms"] > 30) & (curated_df["heavy_atoms"] <= 35)]
heavy_atom100_df = curated_df[curated_df["heavy_atoms"] > 35 ]
heavy_atom_average_df = curated_df[curated_df["heavy_atoms"] == 30.626933 ]

# %%
# check to see if filter works
heavy_atom50_df.head()
# Out:
#        chembl_id  conf_id                                             smiles  \
# 1     CHEMBL1000  conf_00  [H]OC(=O)C([H])([H])OC([H])([H])C([H])([H])N1C...
# 4   CHEMBL100004  conf_00  [H]O/C(OC([H])([H])C([H])([H])[H])=C1\C(C([H])...
# 5   CHEMBL100005  conf_02  [H]c1c([H])c(C([H])([H])[C@]([H])(C(=O)OC([H])...
# 9   CHEMBL100020  conf_00  [H]c1c([H])c([H])c(C(=O)N([H])C(=S)N([H])C([H]...
# 10  CHEMBL100029  conf_02  [H]c1c([H])c([H])c(-c2c(C([H])([H])C(=O)N3C([H...
#
#             mw  atoms  heavy_atoms  heteroatoms  rotatable_bonds  \
# 1   388.155370     52           27            6                8
# 4   375.150429     51           26            6               12
# 5   385.131408     48           29            5                5
# 9   381.187483     54           27            5                6
# 10  318.173213     46           24            3                3
#
#     stereocenters  rings  hbond_acceptors  hbond_donors  \
# 1               1      3                5             1
# 4               1      2                6             1
# 5               1      5                5             0
# 9               0      3                3             2
# 10              0      4                1             1
#
#     significant_negative_wavenumbers  nonunique_smiles  GFN2_TOTAL_ENERGY  \
# 1                              False             False         -80.315048
# 4                              False             False         -78.009245
# 5                              False             False         -80.294618
# 9                              False             False         -76.992961
# 10                             False             False         -66.142124
#
#     GFN2_ATOMIC_ENERGY  GFN2_FORMATION_ENERGY  GFN2_TOTAL_ENTHALPY  \
# 1           -68.493287             -11.821760           -79.870590
# 4           -66.525705             -11.483539           -77.573112
# 5           -68.191537             -12.103081           -79.903792
# 9           -64.808091             -12.184870           -76.521272
# 10          -55.295100             -10.847024           -65.742347
#
#     GFN2_TOTAL_FREE_ENERGY  GFN2_DIPOLE_X  GFN2_DIPOLE_Y  GFN2_DIPOLE_Z  \
# 1               -79.950811          2.379         -3.195          4.509
# 4               -77.659095         -6.628          0.168          2.814
# 5               -79.981805          2.318         -2.097          1.395
# 9               -76.603247          2.780         -1.606          2.897
# 10              -65.813407          2.137         -2.821         -1.215
#
#     GFN2_DIPOLE_TOT  GFN2_QUADRUPOLE_XX  GFN2_QUADRUPOLE_XY  \
# 1             6.017               5.337             -25.657
# 4             7.203              13.223              -5.233
# 5             3.422             -11.183              11.157
# 9             4.325              29.157              -1.367
# 10            3.742              18.637               5.919
#
#     GFN2_QUADRUPOLE_YY  GFN2_QUADRUPOLE_XZ  GFN2_QUADRUPOLE_yz  \
# 1               -4.502              -1.798              11.798
# 4               -9.217              -3.183               3.113
# 5               14.122               3.898              -3.877
# 9               -8.433              14.356              11.052
# 10             -11.163              -4.685               1.082
#
#     GFN2_QUADRUPOLE_ZZ  GFN2_ROT_CONSTANT_A  GFN2_ROT_CONSTANT_B  \
# 1               -0.835             0.009034             0.002935
# 4               -4.005             0.012093             0.002612
# 5               -2.939             0.008664             0.004723
# 9              -20.723             0.012666             0.001637
# 10              -7.475             0.009194             0.005835
#
#     GFN2_ROT_CONSTANT_C  GFN2_ENTHALPY_VIB  GFN2_ENTHALPY_ROT  \
# 1              0.002678          14005.394            888.752
# 4              0.002261          15834.103            888.752
# 5              0.003824          13518.505            888.752
# 9              0.001545          14311.707            888.752
# 10             0.003898          11346.835            888.752
#
#     GFN2_ENTHALPY_TRANSL  GFN2_ENTHALPY_TOT  GFN2_HEAT_CAPACITY_VIB  \
# 1               1481.254          16375.401                  91.382
# 4               1481.254          18204.109                  97.510
# 5               1481.254          15888.511                  89.200
# 9               1481.254          16681.713                  92.662
# 10              1481.254          13716.841                  76.677
#
#     GFN2_HEAT_CAPACITY_ROT  GFN2_HEAT_CAPACITY_TRANSL  GFN2_HEAT_CAPACITY_TOT  \
# 1                    2.981                      4.968                  99.331
# 4                    2.981                      4.968                 105.459
# 5                    2.981                      4.968                  97.149
# 9                    2.981                      4.968                 100.611
# 10                   2.981                      4.968                  84.626
#
#     GFN2_ENTROPY_VIB  GFN2_ENTROPY_ROT  GFN2_ENTROPY_TRANSL  GFN2_ENTROPY_TOT  \
# 1             88.721            36.373               43.746           168.840
# 4            100.957            36.367               43.642           180.966
# 5             84.884            35.588               43.720           164.191
# 9             91.679            37.164               43.690           172.532
# 10            71.108            35.300               43.151           149.559
#
#     GFN2_HOMO_ENERGY  GFN2_LUMO_ENERGY  GFN2_HOMO_LUMO_GAP  GFN2_FERMI_LEVEL  \
# 1          -0.352364         -0.237194            0.115170         -0.294779
# 4          -0.353439         -0.283588            0.069851         -0.318514
# 5          -0.361360         -0.293061            0.068298         -0.327211
# 9          -0.347090         -0.288399            0.058691         -0.317601
# 10         -0.348921         -0.240304            0.108617         -0.294612
#
#     GFN2_DISPERSION_COEFFICIENT_MOLECULAR  GFN2_POLARIZABILITY_MOLECULAR  \
# 1                            31094.695246                     272.494292
# 4                            29419.012760                     265.673033
# 5                            30460.483535                     274.751815
# 9                            33802.572084                     287.917301
# 10                           24255.083159                     244.256587
#
#     DFT_TOTAL_ENERGY  DFT_ATOMIC_ENERGY  DFT_FORMATION_ENERGY  DFT_DIPOLE_X  \
# 1       -1609.322700       -1600.285930             -9.036771      2.142420
# 4       -1529.710027       -1520.925372             -8.784655     -6.228561
# 5       -1280.302706       -1271.130885             -9.171821      2.232262
# 9       -1491.069698       -1481.641351             -9.428347      2.791788
# 10       -997.220303        -988.836443             -8.383860      1.440278
#
#     DFT_DIPOLE_Y  DFT_DIPOLE_Z  DFT_DIPOLE_TOT  DFT_ROT_CONSTANT_A  \
# 1      -2.785717      4.253252        5.517276            0.008840
# 4       1.164321      2.815141        6.933659            0.012092
# 5      -1.689740      1.644240        3.246805            0.008647
# 9      -1.150492      2.493658        3.916126            0.012544
# 10     -2.397156     -1.614596        3.229191            0.009157
#
#     DFT_ROT_CONSTANT_B  DFT_ROT_CONSTANT_C  DFT_XC_ENERGY  \
# 1             0.002865            0.002636    -132.809395
# 4             0.002591            0.002246    -128.312742
# 5             0.004717            0.003817    -123.306232
# 9             0.001617            0.001527    -127.799267
# 10            0.005705            0.003836     -99.386588
#
#     DFT_NUCLEAR_REPULSION_ENERGY  DFT_ONE_ELECTRON_ENERGY  \
# 1                    2659.135307             -7485.087002
# 4                    2455.485098             -6971.678300
# 5                    2770.708763             -7250.024688
# 9                    2382.284705             -6765.768603
# 10                   1968.251156             -5261.850209
#
#     DFT_TWO_ELECTRON_ENERGY  DFT_HOMO_ENERGY  DFT_LUMO_ENERGY  \
# 1               3349.488535        -0.296513         0.044311
# 4               3114.833616        -0.274412        -0.002106
# 5               3322.364334        -0.276278        -0.019839
# 9               3020.256388        -0.289296        -0.000877
# 10              2395.802299        -0.264223         0.032821
#
#     DFT_HOMO_LUMO_GAP                                        rdkit_smile  \
# 1            0.340824   O=C(O)COCCN1CCN([C@@H](c2ccccc2)c2ccc(Cl)cc2)CC1
# 4            0.272307  CCO/C(O)=C1/C(C)=NC(C)=C(C(=O)OCCSc2ccccc2)[C@...
# 5            0.256438  COC(=O)[C@@H](Cc1ccc2c(c1)OCO2)c1c2ccccc2nc2cc...
# 9            0.288420          O=C(NC(=S)NCCC1CCN(Cc2ccccc2)CC1)c1ccccc1
# 10           0.297044          O=C(Cc1c(-c2ccccc2)[nH]c2ccccc12)N1CCCCC1
#
#                     compound_id  VALUE_NUM_mean  VALUE_NUM_std  Perc_Var  \
# 1   ZKLPARSLTMPFCP-NRFANRHFSA-N        0.333456       0.006397  2.209649
# 4   CUHAMGYOMBKPLA-BQOWYSNXSA-N        0.272592       0.003115  0.104604
# 5   KXSQTEDQWJHEDB-SFHVURJKSA-N        0.256484       0.002403  0.017652
# 9   VZGIPERPUUMOQR-UHFFFAOYSA-N        0.286097       0.002208  0.811764
# 10  GFRHLCDSWKISNK-UHFFFAOYSA-N        0.297546       0.002025  0.168715
#
#     Remove_BadDuplicate
# 1                     0
# 4                     0
# 5                     0
# 9                     0
# 10                    0

# %%
heavy_atom25_df = heavy_atom25_df[["chembl_id","compound_id","heavy_atoms","GFN2_HOMO_LUMO_GAP","DFT_HOMO_LUMO_GAP","rdkit_smile"]]
heavy_atom50_df = heavy_atom50_df[["chembl_id","compound_id","heavy_atoms","GFN2_HOMO_LUMO_GAP","DFT_HOMO_LUMO_GAP","rdkit_smile"]]
heavy_atom75_df = heavy_atom75_df[["chembl_id","compound_id","heavy_atoms","GFN2_HOMO_LUMO_GAP","DFT_HOMO_LUMO_GAP","rdkit_smile"]]
heavy_atom100_df = heavy_atom100_df[["chembl_id","compound_id","heavy_atoms","GFN2_HOMO_LUMO_GAP","DFT_HOMO_LUMO_GAP","rdkit_smile"]]
heavy_atom_average_df = heavy_atom_average_df[["chembl_id","compound_id","heavy_atoms","GFN2_HOMO_LUMO_GAP","DFT_HOMO_LUMO_GAP","rdkit_smile"]]

# %%
heavy_atom50_df.head()
# Out:
#        chembl_id                  compound_id  heavy_atoms  \
# 1     CHEMBL1000  ZKLPARSLTMPFCP-NRFANRHFSA-N           27
# 4   CHEMBL100004  CUHAMGYOMBKPLA-BQOWYSNXSA-N           26
# 5   CHEMBL100005  KXSQTEDQWJHEDB-SFHVURJKSA-N           29
# 9   CHEMBL100020  VZGIPERPUUMOQR-UHFFFAOYSA-N           27
# 10  CHEMBL100029  GFRHLCDSWKISNK-UHFFFAOYSA-N           24
#
#     GFN2_HOMO_LUMO_GAP  DFT_HOMO_LUMO_GAP  \
# 1             0.115170           0.340824
# 4             0.069851           0.272307
# 5             0.068298           0.256438
# 9             0.058691           0.288420
# 10            0.108617           0.297044
#
#                                           rdkit_smile
# 1    O=C(O)COCCN1CCN([C@@H](c2ccccc2)c2ccc(Cl)cc2)CC1
# 4   CCO/C(O)=C1/C(C)=NC(C)=C(C(=O)OCCSc2ccccc2)[C@...
# 5   COC(=O)[C@@H](Cc1ccc2c(c1)OCO2)c1c2ccccc2nc2cc...
# 9           O=C(NC(=S)NCCC1CCN(Cc2ccccc2)CC1)c1ccccc1
# 10          O=C(Cc1c(-c2ccccc2)[nH]c2ccccc12)N1CCCCC1

# %% [markdown]
# #### heavy atoms, 25 percentile

# %%
# find distribution of different heavy atom numbers
heavy_atom25_df.heavy_atoms.value_counts().plot(kind='bar', figsize = (8,8))
# Out:
# <AxesSubplot:>

# %%
# examine GFN2 HOMO LUMO GAP Value PER Compound Id
heavy_atom25_types = heavy_atom25_df.pivot_table(index = 'compound_id', columns = 'heavy_atoms', values='GFN2_HOMO_LUMO_GAP', aggfunc='mean')
heavy_atom25_types.hist(figsize=(13,13));

# %%
# scatter plots
sns.scatterplot(x = 'heavy_atoms', y='GFN2_HOMO_LUMO_GAP', data = heavy_atom25_df, label= 'GFN2', marker = 'o')
# Plotting dft values
sns.scatterplot(x = 'heavy_atoms', y='DFT_HOMO_LUMO_GAP', data = heavy_atom25_df, label='DFT', marker='x')

plt.title('GFN2 and DFT values vs. Number of Atoms')
plt.xlabel('Number of Heavy Atoms')
plt.ylabel('Values')
plt.legend()
plt.show()

# %%
# Compute the correlation matrix
corr_matrix = heavy_atom25_df[['heavy_atoms', 'GFN2_HOMO_LUMO_GAP']].corr()

# Plot the heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Heatmap of Correlation between number of Heavy atoms and gfn2 gap values')
plt.show()

# %%
# Histogram for gfn2 values
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.histplot(heavy_atom25_df['GFN2_HOMO_LUMO_GAP'], kde=True, bins=30)
plt.title('Histogram for GFN2 gap values')

# Histogram for dft values
plt.subplot(1, 2, 2)
sns.histplot(heavy_atom25_df['DFT_HOMO_LUMO_GAP'], kde=True, bins=30)
plt.title('Histogram for DFT gap values')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### heavy atoms, 50 percentile

# %%
# find distribution of different heavy atom numbers
heavy_atom50_df.heavy_atoms.value_counts().plot(kind='bar', figsize = (8,8))
# Out:
# <AxesSubplot:>

# %%
# examine GFN2 HOMO LUMO GAP Value PER Compound Id
heavy_atom50_types = heavy_atom50_df.pivot_table(index = 'compound_id', columns = 'heavy_atoms', values='GFN2_HOMO_LUMO_GAP', aggfunc='mean')
heavy_atom50_types.hist(figsize=(13,13));

# %%
# scatter plots
sns.scatterplot(x = 'heavy_atoms', y='GFN2_HOMO_LUMO_GAP', data = heavy_atom50_df, label= 'GFN2', marker = 'o')
# Plotting dft values
sns.scatterplot(x = 'heavy_atoms', y='DFT_HOMO_LUMO_GAP', data = heavy_atom50_df, label='DFT', marker='x')

plt.title('GFN2 and DFT values vs. Number of Atoms')
plt.xlabel('Number of Heavy Atoms')
plt.ylabel('Values')
plt.legend()
plt.show()

# %%
# Compute the correlation matrix
corr_matrix = heavy_atom50_df[['heavy_atoms', 'GFN2_HOMO_LUMO_GAP']].corr()

# Plot the heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Heatmap of Correlation between number of Heavy atoms and gfn2 gap values')
plt.show()

# %%
# Histogram for gfn2 values
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.histplot(heavy_atom50_df['GFN2_HOMO_LUMO_GAP'], kde=True, bins=30)
plt.title('Histogram for GFN2 gap values')

# Histogram for dft values
plt.subplot(1, 2, 2)
sns.histplot(heavy_atom50_df['DFT_HOMO_LUMO_GAP'], kde=True, bins=30)
plt.title('Histogram for DFT gap values')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### heavy atoms, 75 percentile

# %%
# find distribution of different heavy atom numbers
heavy_atom75_df.heavy_atoms.value_counts().plot(kind='bar', figsize = (8,8))
# Out:
# <AxesSubplot:>

# %%
# examine GFN2 HOMO LUMO GAP Value PER Compound Id
heavy_atom75_types = heavy_atom75_df.pivot_table(index = 'compound_id', columns = 'heavy_atoms', values='GFN2_HOMO_LUMO_GAP', aggfunc='mean')
heavy_atom75_types.hist(figsize=(13,13));

# %%
# scatter plots
sns.scatterplot(x = 'heavy_atoms', y='GFN2_HOMO_LUMO_GAP', data = heavy_atom75_df, label= 'GFN2', marker = 'o')
# Plotting dft values
sns.scatterplot(x = 'heavy_atoms', y='DFT_HOMO_LUMO_GAP', data = heavy_atom75_df, label='DFT', marker='x')

plt.title('GFN2 and DFT values vs. Number of Atoms')
plt.xlabel('Number of Heavy Atoms')
plt.ylabel('Values')
plt.legend()
plt.show()

# %%
# Compute the correlation matrix
corr_matrix = heavy_atom75_df[['heavy_atoms', 'GFN2_HOMO_LUMO_GAP']].corr()

# Plot the heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Heatmap of Correlation between number of Heavy atoms and gfn2 gap values')
plt.show()

# %%
# Histogram for gfn2 values
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.histplot(heavy_atom75_df['GFN2_HOMO_LUMO_GAP'], kde=True, bins=30)
plt.title('Histogram for GFN2 gap values')

# Histogram for dft values
plt.subplot(1, 2, 2)
sns.histplot(heavy_atom75_df['DFT_HOMO_LUMO_GAP'], kde=True, bins=30)
plt.title('Histogram for DFT gap values')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### heavy atoms, 100 percentile

# %%
# find distribution of different heavy atom numbers
heavy_atom100_df.heavy_atoms.value_counts().plot(kind='bar', figsize = (8,8))
# Out:
# <AxesSubplot:>

# %%
# examine GFN2 HOMO LUMO GAP Value PER Compound Id
heavy_atom100_types = heavy_atom75_df.pivot_table(index = 'compound_id', columns = 'heavy_atoms', values='GFN2_HOMO_LUMO_GAP', aggfunc='mean')
heavy_atom100_types.hist(figsize=(13,13));

# %%
# scatter plots
sns.scatterplot(x = 'heavy_atoms', y='GFN2_HOMO_LUMO_GAP', data = heavy_atom100_df, label= 'GFN2', marker = 'o')
# Plotting dft values
sns.scatterplot(x = 'heavy_atoms', y='DFT_HOMO_LUMO_GAP', data = heavy_atom100_df, label='DFT', marker='x')

plt.title('GFN2 and DFT values vs. Number of Atoms')
plt.xlabel('Number of Heavy Atoms')
plt.ylabel('Values')
plt.legend()
plt.show()

# %%
# Compute the correlation matrix
corr_matrix = heavy_atom100_df[['heavy_atoms', 'GFN2_HOMO_LUMO_GAP']].corr()

# Plot the heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Heatmap of Correlation between number of Heavy atoms and gfn2 gap values')
plt.show()

# %%
# Histogram for gfn2 values
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.histplot(heavy_atom100_df['GFN2_HOMO_LUMO_GAP'], kde=True, bins=30)
plt.title('Histogram for GFN2 gap values')

# Histogram for dft values
plt.subplot(1, 2, 2)
sns.histplot(heavy_atom100_df['DFT_HOMO_LUMO_GAP'], kde=True, bins=30)
plt.title('Histogram for DFT gap values')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### heavy atoms, average

# %%
# find distribution of average heavy atom numbers
heavy_atom_average_df.heavy_atoms.value_counts().plot(kind='bar', figsize = (8,8))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-38-7729321c54d5> in <module>
#       1 # find distribution of average heavy atom numbers
# ----> 2 heavy_atom_average_df.heavy_atoms.value_counts().plot(kind='bar', figsize = (8,8))
#
# ~/atomsci/lib/python3.8/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     970                     data.columns = label_name
#     971
# --> 972         return plot_backend.plot(data, kind=kind, **kwargs)
#     973
#     974     __call__.__doc__ = __doc__
#
# ~/atomsci/lib/python3.8/site-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71     plot_obj.generate()
#      72     plot_obj.draw()
#      73     return plot_obj.result
#
# ~/atomsci/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py in generate(self)
#     293         for ax in self.axes:
#     294             self._post_plot_logic_common(ax, self.data)
# --> 295             self._post_plot_logic(ax, self.data)
#     296
#     297     def _args_adjust(self):
#
# ~/atomsci/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py in _post_plot_logic(self, ax, data)
#    1526         name = self._get_index_name()
#    1527
# -> 1528         s_edge = self.ax_pos[0] - 0.25 + self.lim_offset
#    1529         e_edge = self.ax_pos[-1] + 0.25 + self.bar_width + self.lim_offset
#    1530
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %% [markdown]
# ## Molecular Weight and gap values

# %% [markdown]
# #### mw

# %%
mw25_df = curated_df[curated_df["mw"] <= 349.226646]
mw50_df = curated_df[(curated_df["mw"] > 349.226646) & (curated_df["mw"] <= 418.140783)]
mw75_df = curated_df[(curated_df["mw"] > 418.140783) & (curated_df["mw"] <= 491.118478)]
mw100_df = curated_df[curated_df["mw"] > 491.118478 ]
mw_average_df = curated_df[curated_df["mw"] == 432.990678 ]

# %%
# check to see if filter works
mw25_df.head()
# Out:
#        chembl_id  conf_id                                             smiles  \
# 3   CHEMBL100003  conf_00  [H]O/C(OC([H])([H])[H])=C1\C(C([H])([H])[H])=N...
# 6   CHEMBL100010  conf_01  [H]c1c([H])c([H])c(C2=C(C(=O)OC([H])([H])[H])[...
# 10  CHEMBL100029  conf_02  [H]c1c([H])c([H])c(-c2c(C([H])([H])C(=O)N3C([H...
# 12  CHEMBL100031  conf_00  [H]c1c([H])c([H])c(N2C([H])([H])C([H])([H])N(C...
# 15  CHEMBL100035  conf_00  [H]ON([H])C(=O)/C(=C(\[H])c1c([H])c([H])c(N([H...
#
#             mw  atoms  heavy_atoms  heteroatoms  rotatable_bonds  \
# 3   281.162708     43           20            5               11
# 6   242.130680     36           18            2                3
# 10  318.173213     46           24            3                3
# 12  337.176342     44           25            9                5
# 15  332.083078     39           23            7                7
#
#     stereocenters  rings  hbond_acceptors  hbond_donors  \
# 3               1      1                5             1
# 6               2      3                2             0
# 10              0      4                1             1
# 12              0      4                9             2
# 15              0      2                4             3
#
#     significant_negative_wavenumbers  nonunique_smiles  GFN2_TOTAL_ENERGY  \
# 3                              False             False         -63.044635
# 6                              False             False         -51.591222
# 10                             False             False         -66.142124
# 12                             False             False         -70.265618
# 15                             False             False         -67.696635
#
#     GFN2_ATOMIC_ENERGY  GFN2_FORMATION_ENERGY  GFN2_TOTAL_ENTHALPY  \
# 3           -53.625801              -9.418834           -62.664873
# 6           -43.310646              -8.280577           -51.275771
# 10          -55.295100             -10.847024           -65.742347
# 12          -59.621332             -10.644286           -69.897455
# 15          -58.416999              -9.279636           -67.383921
#
#     GFN2_TOTAL_FREE_ENERGY  GFN2_DIPOLE_X  GFN2_DIPOLE_Y  GFN2_DIPOLE_Z  \
# 3               -62.740190         -4.793         -0.892          0.956
# 6               -51.336977         -1.431         -1.052          1.317
# 10              -65.813407          2.137         -2.821         -1.215
# 12              -69.970578          4.427         -4.023         -1.482
# 15              -67.458518         -3.182         -4.435          3.746
#
#     GFN2_DIPOLE_TOT  GFN2_QUADRUPOLE_XX  GFN2_QUADRUPOLE_XY  \
# 3             4.970              29.019               4.478
# 6             2.212               0.485              -4.154
# 10            3.742              18.637               5.919
# 12            6.163              18.075              -6.293
# 15            6.621             -14.550              28.837
#
#     GFN2_QUADRUPOLE_YY  GFN2_QUADRUPOLE_XZ  GFN2_QUADRUPOLE_yz  \
# 3               -8.898             -11.014              -3.925
# 6                3.922               3.976               1.385
# 10             -11.163              -4.685               1.082
# 12              -8.942              12.813              -2.736
# 15              -0.116              15.901               3.727
#
#     GFN2_QUADRUPOLE_ZZ  GFN2_ROT_CONSTANT_A  GFN2_ROT_CONSTANT_B  \
# 3              -20.121             0.017387             0.007241
# 6               -4.407             0.019705             0.012370
# 10              -7.475             0.009194             0.005835
# 12              -9.133             0.015622             0.003642
# 15              14.666             0.017382             0.002983
#
#     GFN2_ROT_CONSTANT_C  GFN2_ENTHALPY_VIB  GFN2_ENTHALPY_ROT  \
# 3              0.006572          12871.935            888.752
# 6              0.008719           8477.505            888.752
# 10             0.003898          11346.835            888.752
# 12             0.003377          12160.832            888.752
# 15             0.002719          12437.129            888.752
#
#     GFN2_ENTHALPY_TRANSL  GFN2_ENTHALPY_TOT  GFN2_HEAT_CAPACITY_VIB  \
# 3               1481.254          15241.942                  78.134
# 6               1481.254          10847.511                  56.574
# 10              1481.254          13716.841                  76.677
# 12              1481.254          14530.838                  80.714
# 15              1481.254          14807.135                  79.285
#
#     GFN2_HEAT_CAPACITY_ROT  GFN2_HEAT_CAPACITY_TRANSL  GFN2_HEAT_CAPACITY_TOT  \
# 3                    2.981                      4.968                  86.083
# 6                    2.981                      4.968                  64.523
# 10                   2.981                      4.968                  84.626
# 12                   2.981                      4.968                  88.663
# 15                   2.981                      4.968                  87.234
#
#     GFN2_ENTROPY_VIB  GFN2_ENTROPY_ROT  GFN2_ENTROPY_TRANSL  GFN2_ENTROPY_TOT  \
# 3             81.802            33.934               42.782           158.518
# 6             53.486            32.996               42.337           128.820
# 10            71.108            35.300               43.151           149.559
# 12            75.192            35.384               43.323           153.899
# 15            78.033            35.692               43.279           157.003
#
#     GFN2_HOMO_ENERGY  GFN2_LUMO_ENERGY  GFN2_HOMO_LUMO_GAP  GFN2_FERMI_LEVEL  \
# 3          -0.350243         -0.270147            0.080096         -0.310195
# 6          -0.382563         -0.257754            0.124809         -0.320158
# 10         -0.348921         -0.240304            0.108617         -0.294612
# 12         -0.328885         -0.307294            0.021591         -0.318089
# 15         -0.381235         -0.275218            0.106016         -0.328227
#
#     GFN2_DISPERSION_COEFFICIENT_MOLECULAR  GFN2_POLARIZABILITY_MOLECULAR  \
# 3                            16751.288449                     195.140373
# 6                            13562.233738                     179.607696
# 10                           24255.083159                     244.256587
# 12                           23583.788924                     237.988269
# 15                           21382.050307                     230.803035
#
#     DFT_TOTAL_ENERGY  DFT_ATOMIC_ENERGY  DFT_FORMATION_ENERGY  DFT_DIPOLE_X  \
# 3        -940.100277        -932.957960             -7.142316     -4.986451
# 6        -770.202248        -763.767820             -6.434427     -1.417204
# 10       -997.220303        -988.836443             -8.383860      1.440278
# 12      -1112.723021       -1105.018704             -7.704317      4.338877
# 15      -1426.586418       -1419.732956             -6.853462     -3.140380
#
#     DFT_DIPOLE_Y  DFT_DIPOLE_Z  DFT_DIPOLE_TOT  DFT_ROT_CONSTANT_A  \
# 3      -0.869709      2.092616        5.477238            0.017294
# 6      -0.444106      0.700524        1.642081            0.019608
# 10     -2.397156     -1.614596        3.229191            0.009157
# 12     -3.856202     -1.117755        5.911474            0.015356
# 15     -3.849086      3.246274        5.934285            0.017028
#
#     DFT_ROT_CONSTANT_B  DFT_ROT_CONSTANT_C  DFT_XC_ENERGY  \
# 3             0.007228            0.006575     -90.337873
# 6             0.012267            0.008648     -76.098435
# 10            0.005705            0.003836     -99.386588
# 12            0.003569            0.003302    -107.746079
# 15            0.002968            0.002710    -116.283713
#
#     DFT_NUCLEAR_REPULSION_ENERGY  DFT_ONE_ELECTRON_ENERGY  \
# 3                    1704.654877             -4667.691840
# 6                    1340.771960             -3707.556233
# 10                   1968.251156             -5261.850209
# 12                   2153.643180             -5789.620521
# 15                   1974.977836             -5872.802568
#
#     DFT_TWO_ELECTRON_ENERGY  DFT_HOMO_ENERGY  DFT_LUMO_ENERGY  \
# 3               2113.309805        -0.263692         0.011718
# 6               1672.709355        -0.306396         0.030075
# 10              2395.802299        -0.264223         0.032821
# 12              2631.036540        -0.253953        -0.026702
# 15              2587.548786        -0.295497         0.006381
#
#     DFT_HOMO_LUMO_GAP                                  rdkit_smile  \
# 3            0.275410  CCC[C@@H]1C(C(=O)OCC)=C(C)N=C(C)/C1=C(\O)OC
# 6            0.336471      COC(=O)C1=C(c2ccccc2)C[C@@H]2CC[C@H]1C2
# 10           0.297044    O=C(Cc1c(-c2ccccc2)[nH]c2ccccc12)N1CCCCC1
# 12           0.227251      Nc1nc(N)c2nc(CN3CCN(c4ccccc4)CC3)nnc2n1
# 15           0.301878  C/C(=C\c1ccc(NS(=O)(=O)c2ccccc2)cc1)C(=O)NO
#
#                     compound_id  VALUE_NUM_mean  VALUE_NUM_std  Perc_Var  \
# 3   FCFUFMMLEUYHMD-CDZMIXDFSA-N        0.282891       0.007237  2.644696
# 6   BXNXEXWOZMNHST-YPMHNXCESA-N        0.337342       0.002364  0.258233
# 10  GFRHLCDSWKISNK-UHFFFAOYSA-N        0.297546       0.002025  0.168715
# 12  YUVQKQXYTRSMCD-UHFFFAOYSA-N        0.235240       0.010249  3.396140
# 15  RCHSCTGFXSOIJV-VAWYXSNFSA-N        0.302061       0.002044  0.060485
#
#     Remove_BadDuplicate
# 3                     0
# 6                     0
# 10                    0
# 12                    0
# 15                    0

# %% [markdown]
# #### mw, 25 percentile

# %%
# find distribution of different molecular weights
mw25_df.mw.value_counts().plot(kind='bar', figsize = (8,8))
# Out:
# <AxesSubplot:>

# %%
# examine GFN2 HOMO LUMO GAP Value PER Compound Id
mw25_types = mw25_df.pivot_table(index = 'compound_id', columns = 'mw', values='GFN2_HOMO_LUMO_GAP', aggfunc='mean')
mw25_types.hist(figsize=(13,13));

# %%
# scatter plots
sns.scatterplot(x = 'mw', y='GFN2_HOMO_LUMO_GAP', data = mw25_df, label= 'GFN2', marker = 'o')
# Plotting dft values
sns.scatterplot(x = 'mw', y='DFT_HOMO_LUMO_GAP', data = mw25_df, label='DFT', marker='x')

plt.title('GFN2 and DFT values vs. Number of Atoms')
plt.xlabel('Number of Molecular Weights')
plt.ylabel('Values')
plt.legend()
plt.show()

# %%
# Compute the correlation matrix
corr_matrix = mw25_df[['mw', 'GFN2_HOMO_LUMO_GAP']].corr()

# Plot the heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Heatmap of Correlation between number of molecular weights and gfn2 gap values')
plt.show()

# %%
# Histogram for gfn2 values
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.histplot(mw25_df['GFN2_HOMO_LUMO_GAP'], kde=True, bins=30)
plt.title('Histogram for GFN2 gap values')

# Histogram for dft values
plt.subplot(1, 2, 2)
sns.histplot(mw25_df['DFT_HOMO_LUMO_GAP'], kde=True, bins=30)
plt.title('Histogram for DFT gap values')

plt.tight_layout()
plt.show()

# %%
### Plots regarding to heavy atoms and gap values

# %% [markdown]
# can predict a greater generation molecule,
# make plots put together to see if there is a shift, overlap with specific region, to see if there are trends,
# functional group : a part of molecule, usually boned with
#
# future: save specific dataset, retest against the model justin prepared to see if they affect the r^2 for the entire dataset.
